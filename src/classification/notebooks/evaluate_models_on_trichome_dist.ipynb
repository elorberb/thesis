# %% [markdown]
# ### Get the Ground Truth Distributions
# First, we will get the ground truth distributions for the patches images and their aggregated images.

# %%
from src.segmentation.evaluation.detectron2_evaluator import Detectron2Evaluator
import os

# varaiables
dataset_path = "/home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44"
images_dir_path = os.path.join(dataset_path, "v0.1")
coco_annotations_path = os.path.join(dataset_path, "annotations", "export_coco-instance_etaylor_cannabis_patches_test_26-04-2024_15-44-44_v0.1.json")
yolo_annotations_dir_path = os.path.join(dataset_path, "annotations", "yolo", "labels", "export_coco-instance_etaylor_cannabis_patches_test_26-04-2024_15-44-44_v0.1")

# get evalutor and get the ground truth boxes
detectron2_evaluator = Detectron2Evaluator(num_classes=3,coco_annotations_file_path=coco_annotations_path)
dataset_gt_boxes = detectron2_evaluator.get_annotations_for_dataset(images_directory=images_dir_path)

# %%
def calculate_trichome_distribution(annotations_dict):
    distribution_dict = {}
    image_distribution_dict = {}

    for image, patches in annotations_dict.items():
        image_distribution = {0: 0, 1: 0, 2: 0}
        distribution_dict[image] = {}

        for patch, annotations in patches.items():
            patch_distribution = {0: 0, 1: 0, 2: 0}

            for annotation in annotations:
                class_id = annotation['class_id']
                patch_distribution[class_id] += 1
                image_distribution[class_id] += 1

            distribution_dict[image][patch] = patch_distribution

        image_distribution_dict[image] = image_distribution

    return distribution_dict, image_distribution_dict

# %%
patch_distribution, image_distribution = calculate_trichome_distribution(dataset_gt_boxes)

# %%
# Print results
print("Patch Distribution:")
for image, patches in patch_distribution.items():
    print(f"\n{image}:")
    for patch, dist in patches.items():
        print(f"  {patch}: {dist}")

print("\nImage Distribution:")
for image, dist in image_distribution.items():
    print(f"{image}: {dist}")
# Out:
# Patch Distribution:
#
# IMG_0058:
#   IMG_0058_p0.png: {0: 6, 1: 2, 2: 0}
#   IMG_0058_p1.png: {0: 16, 1: 2, 2: 0}
#   IMG_0058_p2.png: {0: 14, 1: 7, 2: 0}
#   IMG_0058_p3.png: {0: 7, 1: 6, 2: 0}
#   IMG_0058_p4.png: {0: 3, 1: 1, 2: 0}
#   IMG_0058_p5.png: {0: 3, 1: 1, 2: 0}
#   IMG_0058_p6.png: {0: 9, 1: 4, 2: 0}
#   IMG_0058_p7.png: {0: 12, 1: 5, 2: 0}
#   IMG_0058_p8.png: {0: 7, 1: 3, 2: 0}
#
# IMG_1096:
#   IMG_1096_p0.png: {0: 0, 1: 6, 2: 1}
#   IMG_1096_p10.png: {0: 3, 1: 22, 2: 7}
#   IMG_1096_p11.png: {0: 1, 1: 8, 2: 4}
#   IMG_1096_p12.png: {0: 3, 1: 9, 2: 3}
#   IMG_1096_p1.png: {0: 0, 1: 1, 2: 2}
#   IMG_1096_p3.png: {0: 0, 1: 4, 2: 0}
#   IMG_1096_p4.png: {0: 0, 1: 11, 2: 9}
#   IMG_1096_p6.png: {0: 5, 1: 5, 2: 3}
#   IMG_1096_p7.png: {0: 0, 1: 3, 2: 2}
#   IMG_1096_p8.png: {0: 5, 1: 17, 2: 5}
#   IMG_1096_p9.png: {0: 5, 1: 23, 2: 3}
#
# IMG_2198:
#   IMG_2198_p0.png: {0: 0, 1: 4, 2: 0}
#   IMG_2198_p10.png: {0: 4, 1: 5, 2: 0}
#   IMG_2198_p11.png: {0: 2, 1: 5, 2: 3}
#   IMG_2198_p12.png: {0: 3, 1: 7, 2: 1}
#   IMG_2198_p1.png: {0: 2, 1: 4, 2: 0}
#   IMG_2198_p2.png: {0: 5, 1: 16, 2: 0}
#   IMG_2198_p3.png: {0: 7, 1: 20, 2: 0}
#   IMG_2198_p4.png: {0: 4, 1: 19, 2: 0}
#   IMG_2198_p5.png: {0: 3, 1: 11, 2: 0}
#   IMG_2198_p6.png: {0: 9, 1: 13, 2: 0}
#   IMG_2198_p7.png: {0: 1, 1: 11, 2: 0}
#   IMG_2198_p8.png: {0: 4, 1: 18, 2: 1}
#   IMG_2198_p9.png: {0: 4, 1: 15, 2: 5}
#
# IMG_1093:
#   IMG_1093_p0.png: {0: 1, 1: 16, 2: 7}
#   IMG_1093_p10.png: {0: 5, 1: 8, 2: 7}
#   IMG_1093_p11.png: {0: 3, 1: 7, 2: 4}
#   IMG_1093_p12.png: {0: 0, 1: 9, 2: 2}
#   IMG_1093_p1.png: {0: 1, 1: 10, 2: 2}
#   IMG_1093_p2.png: {0: 1, 1: 4, 2: 0}
#   IMG_1093_p3.png: {0: 1, 1: 15, 2: 1}
#   IMG_1093_p4.png: {0: 0, 1: 9, 2: 0}
#   IMG_1093_p5.png: {0: 8, 1: 20, 2: 2}
#   IMG_1093_p6.png: {0: 1, 1: 5, 2: 2}
#   IMG_1093_p7.png: {0: 1, 1: 5, 2: 3}
#   IMG_1093_p8.png: {0: 8, 1: 20, 2: 4}
#   IMG_1093_p9.png: {0: 3, 1: 15, 2: 2}
#
# IMG_0542:
#   IMG_0542_p0.png: {0: 3, 1: 0, 2: 0}
#   IMG_0542_p10.png: {0: 1, 1: 7, 2: 0}
#   IMG_0542_p12.png: {0: 3, 1: 10, 2: 0}
#   IMG_0542_p2.png: {0: 1, 1: 5, 2: 0}
#   IMG_0542_p3.png: {0: 2, 1: 5, 2: 0}
#   IMG_0542_p5.png: {0: 3, 1: 13, 2: 0}
#   IMG_0542_p6.png: {0: 11, 1: 7, 2: 0}
#   IMG_0542_p7.png: {0: 7, 1: 0, 2: 0}
#   IMG_0542_p8.png: {0: 5, 1: 1, 2: 0}
#
# IMG_2271:
#   IMG_2271_p0.png: {0: 2, 1: 2, 2: 0}
#   IMG_2271_p10.png: {0: 2, 1: 14, 2: 2}
#   IMG_2271_p11.png: {0: 6, 1: 12, 2: 0}
#   IMG_2271_p1.png: {0: 0, 1: 1, 2: 0}
#   IMG_2271_p2.png: {0: 2, 1: 1, 2: 2}
#   IMG_2271_p3.png: {0: 3, 1: 1, 2: 0}
#   IMG_2271_p4.png: {0: 0, 1: 1, 2: 0}
#   IMG_2271_p5.png: {0: 2, 1: 8, 2: 1}
#   IMG_2271_p6.png: {0: 1, 1: 4, 2: 0}
#   IMG_2271_p7.png: {0: 2, 1: 9, 2: 2}
#   IMG_2271_p8.png: {0: 2, 1: 1, 2: 0}
#   IMG_2271_p9.png: {0: 1, 1: 3, 2: 3}
#
# IMG_0019:
#   IMG_0019_p0.png: {0: 6, 1: 5, 2: 0}
#   IMG_0019_p10.png: {0: 5, 1: 2, 2: 1}
#   IMG_0019_p1.png: {0: 9, 1: 10, 2: 0}
#   IMG_0019_p2.png: {0: 10, 1: 8, 2: 2}
#   IMG_0019_p3.png: {0: 8, 1: 9, 2: 0}
#   IMG_0019_p4.png: {0: 22, 1: 15, 2: 0}
#   IMG_0019_p5.png: {0: 17, 1: 20, 2: 0}
#   IMG_0019_p6.png: {0: 11, 1: 12, 2: 0}
#   IMG_0019_p7.png: {0: 18, 1: 10, 2: 0}
#   IMG_0019_p8.png: {0: 18, 1: 8, 2: 0}
#   IMG_0019_p9.png: {0: 16, 1: 0, 2: 0}
#
# IMG_1079:
#   IMG_1079_p0.png: {0: 7, 1: 12, 2: 1}
#   IMG_1079_p1.png: {0: 6, 1: 6, 2: 0}
#   IMG_1079_p2.png: {0: 9, 1: 6, 2: 0}
#   IMG_1079_p3.png: {0: 8, 1: 20, 2: 0}
#   IMG_1079_p4.png: {0: 22, 1: 16, 2: 0}
#   IMG_1079_p5.png: {0: 3, 1: 6, 2: 2}
#   IMG_1079_p6.png: {0: 3, 1: 3, 2: 0}
#   IMG_1079_p7.png: {0: 10, 1: 10, 2: 1}
#
# IMG_1753:
#   IMG_1753_p1.png: {0: 4, 1: 4, 2: 0}
#   IMG_1753_p2.png: {0: 10, 1: 2, 2: 0}
#   IMG_1753_p3.png: {0: 15, 1: 2, 2: 0}
#   IMG_1753_p4.png: {0: 24, 1: 4, 2: 0}
#   IMG_1753_p5.png: {0: 12, 1: 3, 2: 0}
#   IMG_1753_p6.png: {0: 8, 1: 6, 2: 0}
#
# IMG_2285:
#   IMG_2285_p0.png: {0: 2, 1: 5, 2: 1}
#   IMG_2285_p10.png: {0: 0, 1: 6, 2: 1}
#   IMG_2285_p11.png: {0: 1, 1: 12, 2: 1}
#   IMG_2285_p12.png: {0: 6, 1: 19, 2: 0}
#   IMG_2285_p13.png: {0: 5, 1: 11, 2: 0}
#   IMG_2285_p1.png: {0: 3, 1: 7, 2: 2}
#   IMG_2285_p2.png: {0: 0, 1: 4, 2: 2}
#   IMG_2285_p3.png: {0: 1, 1: 2, 2: 0}
#   IMG_2285_p4.png: {0: 3, 1: 10, 2: 0}
#   IMG_2285_p5.png: {0: 2, 1: 10, 2: 3}
#   IMG_2285_p6.png: {0: 1, 1: 16, 2: 0}
#   IMG_2285_p7.png: {0: 1, 1: 11, 2: 0}
#   IMG_2285_p8.png: {0: 0, 1: 6, 2: 1}
#   IMG_2285_p9.png: {0: 4, 1: 8, 2: 1}
#
# Image Distribution:
# IMG_0058: {0: 77, 1: 31, 2: 0}
# IMG_1096: {0: 22, 1: 109, 2: 39}
# IMG_2198: {0: 48, 1: 148, 2: 10}
# IMG_1093: {0: 33, 1: 143, 2: 36}
# IMG_0542: {0: 36, 1: 48, 2: 0}
# IMG_2271: {0: 23, 1: 57, 2: 10}
# IMG_0019: {0: 140, 1: 99, 2: 3}
# IMG_1079: {0: 68, 1: 79, 2: 4}
# IMG_1753: {0: 73, 1: 21, 2: 0}
# IMG_2285: {0: 29, 1: 127, 2: 12}

# %%
import pandas as pd
# build dataframe from the dicts distributions
images_annotations = []

for image_number, image_dist in image_distribution.items():
    clear_count = image_dist.get(0, 0)
    cloudy_count = image_dist.get(1, 0)
    amber_count = image_dist.get(2, 0)
    total_count = clear_count + cloudy_count + amber_count

    # Calculate normalized distribution
    if total_count > 0:
        clear_normalized = clear_count / total_count
        cloudy_normalized = cloudy_count / total_count
        amber_normalized = amber_count / total_count
    else:
        clear_normalized = cloudy_normalized = amber_normalized = 0

    images_annotations.append({
        "image_number": image_number,
        "clear": clear_count,
        "cloudy": cloudy_count,
        "amber": amber_count,
        "clear_norm": clear_normalized,
        "cloudy_norm": cloudy_normalized,
        "amber_norm": amber_normalized
    })
    
images_gt_df = pd.DataFrame(images_annotations)
images_gt_df
# Out:
#   image_number  clear  cloudy  amber  clear_norm  cloudy_norm  amber_norm
# 0     IMG_0058     77      31      0    0.712963     0.287037    0.000000
# 1     IMG_1096     22     109     39    0.129412     0.641176    0.229412
# 2     IMG_2198     48     148     10    0.233010     0.718447    0.048544
# 3     IMG_1093     33     143     36    0.155660     0.674528    0.169811
# 4     IMG_0542     36      48      0    0.428571     0.571429    0.000000
# 5     IMG_2271     23      57     10    0.255556     0.633333    0.111111
# 6     IMG_0019    140      99      3    0.578512     0.409091    0.012397
# 7     IMG_1079     68      79      4    0.450331     0.523179    0.026490
# 8     IMG_1753     73      21      0    0.776596     0.223404    0.000000
# 9     IMG_2285     29     127     12    0.172619     0.755952    0.071429

# %%
# create patches ground truth dataframe
patches_annotations = []

for image_number, patches in patch_distribution.items():
    for patch_number, patch_dist in patches.items():
        clear_count = patch_dist.get(0, 0)
        cloudy_count = patch_dist.get(1, 0)
        amber_count = patch_dist.get(2, 0)
        total_count = clear_count + cloudy_count + amber_count

        # Calculate normalized distribution
        if total_count > 0:
            clear_normalized = clear_count / total_count
            cloudy_normalized = cloudy_count / total_count
            amber_normalized = amber_count / total_count
        else:
            clear_normalized = cloudy_normalized = amber_normalized = 0

        patches_annotations.append({
            "image_number": image_number,
            "patch_number": patch_number,
            "clear": clear_count,
            "cloudy": cloudy_count,
            "amber": amber_count,
            "clear_norm": clear_normalized,
            "cloudy_norm": cloudy_normalized,
            "amber_norm": amber_normalized
        })
    
patches_gt_df = pd.DataFrame(patches_annotations)
patches_gt_df.head()
# Out:
#   image_number     patch_number  clear  cloudy  amber  clear_norm  \
# 0     IMG_0058  IMG_0058_p0.png      6       2      0    0.750000
# 1     IMG_0058  IMG_0058_p1.png     16       2      0    0.888889
# 2     IMG_0058  IMG_0058_p2.png     14       7      0    0.666667
# 3     IMG_0058  IMG_0058_p3.png      7       6      0    0.538462
# 4     IMG_0058  IMG_0058_p4.png      3       1      0    0.750000
#
#    cloudy_norm  amber_norm
# 0     0.250000         0.0
# 1     0.111111         0.0
# 2     0.333333         0.0
# 3     0.461538         0.0
# 4     0.250000         0.0

# %% [markdown]
# ### Prediction Models Trichomes Distributions
# Here we will use the detection results from the previous experiment done for comparing detections models.
# We will extract the bboxes from the detections of the models and use them to extract trichomes images for evaluation.
# After extracting the trichomes images we will classify them using the Alexnet model and evalute the results.

# %%
# laod the pred boxes of each model
import json
import os
import numpy as np

# load the ultralytics models pred boxes
ultralytics_models_pred_boxes_saveing_path = os.path.join("/home/etaylor/code_projects/thesis/data/models_scores", "ultralytics_models_pred_boxes_result_22_05_2024.json")
detectron2_models_pred_boxes_saveing_path = os.path.join("/home/etaylor/code_projects/thesis/data/models_scores", "detectron2_models_pred_boxes_result_22_05_2024.json")

with open(ultralytics_models_pred_boxes_saveing_path, "r") as f:
    ultralytics_models_pred_boxes = json.load(f)
    
with open(detectron2_models_pred_boxes_saveing_path, "r") as f:
    detectron2_models_pred_boxes = json.load(f)

# %% [markdown]
# ### Create Classification Dataset from Detections
# In this part we will use the detection from the model compared in the last comparison and create dataset that will be used to infrence with the alexnet model.

# %%
import os
import cv2

def create_trichome_dataset_from_detections(detection_dict, images_directory, output_directory, extend_percentage=0):
    # Create output directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)

    # Process each image and crop trichomes
    for image_number, patches_detections in detection_dict.items():
        for patch_file_name, detections in patches_detections.items():
            # Extract patch number from the filename
            patch_number = patch_file_name.split('_p')[1].split('.')[0]
            
            image_path = os.path.join(images_directory, patch_file_name)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Image {image_path} not found or unable to read.")
                continue

            for i, detection in enumerate(detections):
                bbox = detection['bbox']

                x_min, y_min, x_max, y_max = map(int, bbox)

                # Calculate the width and height of the bounding box
                width = x_max - x_min
                height = y_max - y_min

                # Calculate the extension for width and height
                width_extension = int(width * extend_percentage)
                height_extension = int(height * extend_percentage)

                # Extend the bounding box coordinates
                x_min = max(x_min - width_extension, 0)
                y_min = max(y_min - height_extension, 0)
                x_max = min(x_max + width_extension, image.shape[1])
                y_max = min(y_max + height_extension, image.shape[0])

                # Crop the trichome with extended bounding box
                trichome_crop = image[y_min:y_max, x_min:x_max]

                # Save the cropped image with the desired naming convention including patch number
                output_path = os.path.join(output_directory, f"{image_number}_p{patch_number}_trichome_{i}.png")
                cv2.imwrite(output_path, trichome_crop)

                print(f"Cropped trichome saved at: {output_path}")

    print(f"Dataset creation completed. Images saved in {output_directory}")

# %%
detectron2_models_pred_boxes['faster_rcnn_R_50_DC5_1x']

# %%
# creating the trichomes dataset of the faster_rcnn_R_50_DC5_1x mode
saving_path = "/home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x"

create_trichome_dataset_from_detections(detection_dict=detectron2_models_pred_boxes['faster_rcnn_R_50_DC5_1x'],
                                        images_directory=images_dir_path,
                                        output_directory=saving_path,
                                        extend_percentage=0.1)
# Out:
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_21.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_22.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_23.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_24.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_25.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_26.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_27.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_28.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_29.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_30.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_31.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_32.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_33.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p10_trichome_34.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p11_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p1_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p1_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p1_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p1_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p1_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_21.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p12_trichome_22.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p3_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p4_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p8_trichome_21.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p6_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p0_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p0_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p0_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p0_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p0_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p7_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_21.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_22.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_23.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_24.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_25.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_26.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_27.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_28.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_29.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_30.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_31.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_32.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_33.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1096_p9_trichome_34.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p1_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p0_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_1079_p2_trichome_10.png
# ...
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p3_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p3_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_20.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_21.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p1_trichome_22.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p5_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p5_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p5_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p6_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_9.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_10.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_11.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_12.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_13.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_14.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_15.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_16.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_17.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_18.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p7_trichome_19.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p9_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p9_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_4.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_5.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_6.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_7.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p8_trichome_8.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p4_trichome_0.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p4_trichome_1.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p4_trichome_2.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p4_trichome_3.png
# Cropped trichome saved at: /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x/IMG_0058_p4_trichome_4.png
# Dataset creation completed. Images saved in /home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x

# %% [markdown]
# ### Train Alexnet Model
# Now we will fine tune the alexnet model that we will use for the classification task

# %%
from fastai.vision.all import *
from fastai.vision import *

data = {
        'train': '/home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_train_26-04-2024_15-44-44/trichome_dataset_01',
        'test': '/home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/trichome_dataset_01',
    }

# define train metrics
precision_macro_fastai = Precision(average='macro')
recall_macro_fastai = Recall(average='macro')
roc_auc_fastai = RocAuc()


# transformation and image space conversion
def custom_transform(size):
    return Resize(size, method='pad', pad_mode='zeros')

class RGB2HSV(Transform):
    def encodes(self, img: PILImage): 
        return rgb2hsv(img)
    
    
global_item_tfms=custom_transform(size=128),  # Resize and HSV transform
global_batch_tfms=[
    RGB2HSV(),
    *aug_transforms(size=128, flip_vert=True, max_rotate=10),
    Brightness(max_lighting=0.2, p=0.75),
    Contrast(max_lighting=0.2, p=0.75),
]

dls = ImageDataLoaders.from_folder(
        path=data['train'],
        item_tfms=global_item_tfms,
        batch_tfms=global_batch_tfms,
        bs=16,
        valid_pct=0.25
    )

model = vision_learner(
            dls=dls,
            arch=models.alexnet,
            metrics=[error_rate, precision_macro_fastai, recall_macro_fastai, roc_auc_fastai]
        )

model.fine_tune(epochs=100)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.562871</td>
#       <td>1.116674</td>
#       <td>0.458867</td>
#       <td>0.557624</td>
#       <td>0.513517</td>
#       <td>0.755080</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.111726</td>
#       <td>0.822226</td>
#       <td>0.363803</td>
#       <td>0.651030</td>
#       <td>0.589478</td>
#       <td>0.812715</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.028280</td>
#       <td>0.771384</td>
#       <td>0.332724</td>
#       <td>0.664672</td>
#       <td>0.621920</td>
#       <td>0.826882</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.981307</td>
#       <td>0.732131</td>
#       <td>0.308958</td>
#       <td>0.691874</td>
#       <td>0.686212</td>
#       <td>0.845278</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.951773</td>
#       <td>0.696457</td>
#       <td>0.290676</td>
#       <td>0.702461</td>
#       <td>0.702498</td>
#       <td>0.854495</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.905506</td>
#       <td>0.668165</td>
#       <td>0.285192</td>
#       <td>0.712449</td>
#       <td>0.716218</td>
#       <td>0.861481</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.867581</td>
#       <td>0.696895</td>
#       <td>0.288848</td>
#       <td>0.727249</td>
#       <td>0.710823</td>
#       <td>0.861511</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.812123</td>
#       <td>0.640685</td>
#       <td>0.257770</td>
#       <td>0.750013</td>
#       <td>0.725635</td>
#       <td>0.872152</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.815706</td>
#       <td>0.656867</td>
#       <td>0.272395</td>
#       <td>0.746118</td>
#       <td>0.717904</td>
#       <td>0.863809</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.763217</td>
#       <td>0.645630</td>
#       <td>0.270567</td>
#       <td>0.761083</td>
#       <td>0.692654</td>
#       <td>0.866856</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.750255</td>
#       <td>0.629563</td>
#       <td>0.270567</td>
#       <td>0.725668</td>
#       <td>0.704581</td>
#       <td>0.874757</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.761693</td>
#       <td>0.630326</td>
#       <td>0.272395</td>
#       <td>0.733762</td>
#       <td>0.714334</td>
#       <td>0.875510</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.705488</td>
#       <td>0.628363</td>
#       <td>0.268739</td>
#       <td>0.741521</td>
#       <td>0.696697</td>
#       <td>0.872976</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.700191</td>
#       <td>0.667964</td>
#       <td>0.327239</td>
#       <td>0.700194</td>
#       <td>0.651849</td>
#       <td>0.855191</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.712148</td>
#       <td>0.614686</td>
#       <td>0.266910</td>
#       <td>0.759651</td>
#       <td>0.708518</td>
#       <td>0.870649</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.659285</td>
#       <td>0.626176</td>
#       <td>0.287020</td>
#       <td>0.734633</td>
#       <td>0.681665</td>
#       <td>0.866836</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.649282</td>
#       <td>0.639975</td>
#       <td>0.259598</td>
#       <td>0.755228</td>
#       <td>0.708168</td>
#       <td>0.874712</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.633108</td>
#       <td>0.617865</td>
#       <td>0.270567</td>
#       <td>0.763748</td>
#       <td>0.691700</td>
#       <td>0.875267</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.599457</td>
#       <td>0.607735</td>
#       <td>0.274223</td>
#       <td>0.741997</td>
#       <td>0.723713</td>
#       <td>0.876805</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.591813</td>
#       <td>0.618602</td>
#       <td>0.268739</td>
#       <td>0.753806</td>
#       <td>0.708587</td>
#       <td>0.874001</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.601055</td>
#       <td>0.657221</td>
#       <td>0.285192</td>
#       <td>0.744409</td>
#       <td>0.688120</td>
#       <td>0.864135</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.619379</td>
#       <td>0.612320</td>
#       <td>0.274223</td>
#       <td>0.727375</td>
#       <td>0.717973</td>
#       <td>0.881902</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.595163</td>
#       <td>0.590725</td>
#       <td>0.252285</td>
#       <td>0.746800</td>
#       <td>0.746011</td>
#       <td>0.893133</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.598872</td>
#       <td>0.668277</td>
#       <td>0.279707</td>
#       <td>0.775809</td>
#       <td>0.680435</td>
#       <td>0.861200</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.562635</td>
#       <td>0.617036</td>
#       <td>0.243144</td>
#       <td>0.770784</td>
#       <td>0.737029</td>
#       <td>0.878844</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.571477</td>
#       <td>0.650500</td>
#       <td>0.259598</td>
#       <td>0.762852</td>
#       <td>0.724956</td>
#       <td>0.876529</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.572105</td>
#       <td>0.630687</td>
#       <td>0.274223</td>
#       <td>0.764020</td>
#       <td>0.699148</td>
#       <td>0.878808</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.568699</td>
#       <td>0.620997</td>
#       <td>0.263254</td>
#       <td>0.742073</td>
#       <td>0.728085</td>
#       <td>0.875868</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.563513</td>
#       <td>0.646753</td>
#       <td>0.276051</td>
#       <td>0.746831</td>
#       <td>0.694767</td>
#       <td>0.865536</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.559115</td>
#       <td>0.601620</td>
#       <td>0.296161</td>
#       <td>0.715354</td>
#       <td>0.716632</td>
#       <td>0.880841</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.562756</td>
#       <td>0.619736</td>
#       <td>0.259598</td>
#       <td>0.777218</td>
#       <td>0.719310</td>
#       <td>0.880982</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.539501</td>
#       <td>0.643463</td>
#       <td>0.281536</td>
#       <td>0.715256</td>
#       <td>0.739449</td>
#       <td>0.874186</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.555291</td>
#       <td>0.625749</td>
#       <td>0.254113</td>
#       <td>0.756680</td>
#       <td>0.742341</td>
#       <td>0.878480</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.548541</td>
#       <td>0.604239</td>
#       <td>0.272395</td>
#       <td>0.748214</td>
#       <td>0.711754</td>
#       <td>0.880858</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.551737</td>
#       <td>0.609040</td>
#       <td>0.255942</td>
#       <td>0.769623</td>
#       <td>0.711152</td>
#       <td>0.890183</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.500837</td>
#       <td>0.649209</td>
#       <td>0.299817</td>
#       <td>0.680804</td>
#       <td>0.736586</td>
#       <td>0.882661</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.510624</td>
#       <td>0.618939</td>
#       <td>0.268739</td>
#       <td>0.760568</td>
#       <td>0.690173</td>
#       <td>0.883273</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.533257</td>
#       <td>0.666265</td>
#       <td>0.285192</td>
#       <td>0.740148</td>
#       <td>0.682886</td>
#       <td>0.873344</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.519315</td>
#       <td>0.659331</td>
#       <td>0.263254</td>
#       <td>0.765836</td>
#       <td>0.700529</td>
#       <td>0.879586</td>
#       <td>00:02</td>
#     </tr>
#     <tr>

# %%
from collections import defaultdict
import os
import pandas as pd
from fastai.vision.all import *

saving_path = "/home/etaylor/code_projects/thesis/segments/etaylor_cannabis_patches_test_26-04-2024_15-44-44/model_preds_trichomes_datasets/faster_rcnn_R_50_DC5_1x"

# Function to predict a single image
def predict_image(img_path, model):
    img = PILImage.create(img_path)
    pred_class, _, _ = model.predict(img)
    return pred_class

# Function to aggregate results for each patch
def aggregate_patch_results(predictions):
    return {cls: predictions.count(cls) for cls in set(predictions)}

# Dictionary to store predictions for each patch
patch_predictions = defaultdict(list)

# Predict each image and store results
for img_name in os.listdir(saving_path):
    if img_name.endswith('.png'):
        img_path = os.path.join(saving_path, img_name)
        pred_class = predict_image(img_path, model)
        
        # Extract patch name from image name
        patch_name = '_'.join(img_name.split('_')[:3])  # Assumes format like IMG_0019_p10_trichome_5.png
        
        patch_predictions[f"{patch_name}.png"].append(str(pred_class))

# Aggregate results for each patch
aggregated_results = {patch: aggregate_patch_results(preds) for patch, preds in patch_predictions.items()}

# Convert results to a DataFrame
results_df = pd.DataFrame.from_dict(aggregated_results, orient='index')
results_df = results_df.fillna(0).astype(int)  # Replace NaN with 0 and convert to int

# Reset the index, rename it, and add the patch number as a column
results_df = results_df.reset_index()
results_df = results_df.rename(columns={'index': 'Patch Number'})

# Ensure the 'Patch Number' column is the first column
cols = results_df.columns.tolist()
cols = ['Patch Number'] + [col for col in cols if col != 'Patch Number']
results_df = results_df[cols]

# Reset the index to regular numbers
results_df = results_df.reset_index(drop=True)

# %%
print(f"Length of results: {len(results_df)}")
# remove patch_number column from df

results_df.head()
# Out:
# Length of results: 108
#        Patch Number  cloudy  clear  amber
# 0  IMG_1096_p10.png      18      8      9
# 1  IMG_1096_p11.png      10      2      8
# 2   IMG_1096_p1.png       1      1      3
# 3  IMG_1096_p12.png      16      3      4
# 4   IMG_1096_p3.png       1      4      1

# %%
import pandas as pd
import numpy as np

def normalize_patch_scores(df):
    # Create a copy of the original DataFrame
    result_df = df.copy()
    
    # Identify columns to normalize (exclude 'Patch Number')
    columns_to_normalize = [col for col in df.columns if col != 'Patch Number']
    
    # Calculate normalized scores
    normalized_scores = df[columns_to_normalize].div(df[columns_to_normalize].sum(axis=1), axis=0)
    
    # Add normalized scores to the result DataFrame with a 'norm_' prefix
    for column in normalized_scores.columns:
        result_df[f'{column}_norm'] = normalized_scores[column]
    
    return result_df

def aggregate_image_scores(df):
    # Extract image names from 'Patch Number' column
    df['image'] = df['patch_number'].str.split('_p').str[0]
    
    # Identify columns to aggregate (exclude 'Patch Number' and 'image')
    columns_to_aggregate = [col for col in df.columns if col not in ['Patch Number', 'image']]
    
    # Group by image and sum the scores
    image_scores = df.groupby('image')[columns_to_aggregate].sum()
    
    # Normalize the aggregated scores
    normalized_scores = image_scores.div(image_scores.sum(axis=1), axis=0)
    
    # Add normalized scores to the result DataFrame with a 'norm_' prefix
    for column in normalized_scores.columns:
        image_scores[f'{column}_norm'] = normalized_scores[column]
    
    return image_scores

# Normalize patch scores and add to the original DataFrame
patches_pred_df = normalize_patch_scores(results_df)

# Aggregate and normalize image scores
images_pred_df = aggregate_image_scores(results_df)

# %%
patches_pred_df.head()
# Out:
#        patch_number  cloudy  clear  amber  cloudy_norm  clear_norm  amber_norm
# 0  IMG_1096_p10.png      18      8      9     0.514286    0.228571    0.257143
# 1  IMG_1096_p11.png      10      2      8     0.500000    0.100000    0.400000
# 2   IMG_1096_p1.png       1      1      3     0.200000    0.200000    0.600000
# 3  IMG_1096_p12.png      16      3      4     0.695652    0.130435    0.173913
# 4   IMG_1096_p3.png       1      4      1     0.166667    0.666667    0.166667

# %%
patches_gt_df.head()
# Out:
#   image_number     patch_number  clear  cloudy  amber  clear_norm  \
# 0     IMG_0058  IMG_0058_p0.png      6       2      0    0.750000
# 1     IMG_0058  IMG_0058_p1.png     16       2      0    0.888889
# 2     IMG_0058  IMG_0058_p2.png     14       7      0    0.666667
# 3     IMG_0058  IMG_0058_p3.png      7       6      0    0.538462
# 4     IMG_0058  IMG_0058_p4.png      3       1      0    0.750000
#
#    cloudy_norm  amber_norm              patch_id
# 0     0.250000         0.0  IMG_0058_IMG_0058_p0
# 1     0.111111         0.0  IMG_0058_IMG_0058_p1
# 2     0.333333         0.0  IMG_0058_IMG_0058_p2
# 3     0.461538         0.0  IMG_0058_IMG_0058_p3
# 4     0.250000         0.0  IMG_0058_IMG_0058_p4

# %%
# get the records of the patch_number IMG_0058_p0.png from patches_gt_df
val_gt = patches_gt_df[patches_gt_df['patch_number'] == 'IMG_0058_p0.png']
val_pred = patches_pred_df[patches_pred_df['patch_number'] == 'IMG_0058_p0.png']

# %%
print(f"ground truth:\n {val_gt}")
print(f"prediction:\n {val_pred}")
# Out:
# ground truth:
#    image_number     patch_number  clear  cloudy  amber  clear_norm  \
# 0     IMG_0058  IMG_0058_p0.png      6       2      0        0.75
#
#    cloudy_norm  amber_norm              patch_id
# 0         0.25         0.0  IMG_0058_IMG_0058_p0
# prediction:
#         patch_number  cloudy  clear  amber  cloudy_norm  clear_norm  amber_norm
# 98  IMG_0058_p0.png       5      4      0     0.555556    0.444444         0.0

# %% [markdown]
# ### Evaluate Regression Scores

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0  # Exclude zero values to avoid division by zero
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

def calculate_metrics(y_true, y_pred):
    # mse = mean_squared_error(y_true, y_pred)
    # rmse = np.sqrt(mse)
    # mae = mean_absolute_error(y_true, y_pred)
    # r2 = r2_score(y_true, y_pred)
    mape = calculate_mape(y_true, y_pred)
    return {'MAPE': mape}


def evaluate_patch_predictions(patches_gt_df, patches_pred_df, model_name):
    results = {"model_name": model_name}
    trichome_types = ['clear', 'cloudy', 'amber']

    patches_gt_df = patches_gt_df.set_index('patch_number')
    patches_pred_df = patches_pred_df.set_index('patch_number')

    merged_patches = pd.merge(patches_gt_df, patches_pred_df, 
                              left_index=True, right_index=True, 
                              suffixes=('_gt', '_pred'))
    
    # Analyze distribution of predictions
    pred_dist = merged_patches[[f'{t}_norm_pred' for t in trichome_types]]
    gt_dist = merged_patches[[f'{t}_norm_gt' for t in trichome_types]]

    # Plot distribution of predictions
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=pred_dist)
    plt.title(f'Distribution of Normalized Predictions - {model_name}')
    plt.ylabel('Proportion')
    plt.savefig(f'pred_distribution_{model_name}.png')
    plt.close()

    # Plot distribution of ground truth
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=gt_dist)
    plt.title(f'Distribution of Normalized Ground Truth - {model_name}')
    plt.ylabel('Proportion')
    plt.savefig(f'gt_distribution_{model_name}.png')
    plt.close()

    # Compute average proportions
    avg_pred = pred_dist.mean()
    avg_gt = gt_dist.mean()

    for t in trichome_types:
        results[f'Avg_Pred_{t}'] = avg_pred[f'{t}_norm_pred']
        results[f'Avg_GT_{t}'] = avg_gt[f'{t}_norm_gt']

    # Check if predictions sum to 1
    pred_sums = pred_dist.sum(axis=1)
    gt_sums = gt_dist.sum(axis=1)

    results['Pred_Sum_Mean'] = pred_sums.mean()
    results['Pred_Sum_Std'] = pred_sums.std()
    results['GT_Sum_Mean'] = gt_sums.mean()
    results['GT_Sum_Std'] = gt_sums.std()

    # Analyze errors
    for t in trichome_types:
        error = merged_patches[f'{t}_norm_pred'] - merged_patches[f'{t}_norm_gt']
        plt.figure(figsize=(10, 6))
        sns.scatterplot(x=merged_patches[f'{t}_norm_gt'], y=error)
        plt.axhline(y=0, color='r', linestyle='--')
        plt.title(f'Error vs Ground Truth for {t} Trichomes')
        plt.xlabel('Ground Truth')
        plt.ylabel('Error (Predicted - Ground Truth)')
        plt.savefig(f'error_analysis_{t}_{model_name}.png')
        plt.close()

    return pd.DataFrame([results]), merged_patches

# %%
# Usage example:
patch_metrics, merged_patches = evaluate_patch_predictions(patches_gt_df, patches_pred_df, "Faster RCNN with Alexnet")

# %%
patch_metrics
# Out:
#                  model_name  Patch clear MAPE  Patch cloudy MAPE  \
# 0  Faster RCNN with Alexnet         65.501524          63.757282
#
#    Patch amber MAPE  Patch Overall MAPE  Patch norm_clear MAPE  \
# 0         57.805463           63.365174              67.669777
#
#    Patch norm_cloudy MAPE  Patch norm_amber MAPE  Patch norm_Overall MAPE
# 0               40.925158              54.682494                 53.80723

# %%
import matplotlib.pyplot as plt

def plot_prediction_vs_ground_truth(merged_patches, model_name):
    trichome_types = ['clear', 'cloudy', 'amber']
    score_types = ['norm_', '']
    
    for score_type in score_types:
        fig, axes = plt.subplots(1, 3, figsize=(18, 6))
        fig.suptitle(f'{"Normalized" if score_type == "norm_" else "Non-normalized"} Prediction vs Ground Truth for {model_name}')
        
        for i, trichome in enumerate(trichome_types):
            ax = axes[i]
            gt = merged_patches[f'{trichome}_{score_type}gt']
            pred = merged_patches[f'{trichome}_{score_type}pred']
            
            ax.scatter(gt, pred, alpha=0.5)
            
            if score_type == 'norm_':
                ax.plot([0, 1], [0, 1], 'r--')  # diagonal line for normalized data
                ax.set_xlim(0, 1)
                ax.set_ylim(0, 1)
            else:
                max_val = max(gt.max(), pred.max())
                ax.plot([0, max_val], [0, max_val], 'r--')  # diagonal line for non-normalized data
                ax.set_xlim(0, max_val)
                ax.set_ylim(0, max_val)
            
            ax.set_xlabel('Ground Truth')
            ax.set_ylabel('Predicted')
            ax.set_title(f'{trichome.capitalize()} Trichomes')
        
        plt.tight_layout()
        plt.savefig(f'{"normalized" if score_type == "norm_" else "non_normalized"}_prediction_vs_ground_truth_{model_name}.png')
        plt.close()

# %%
# Use this function in your evaluate_patch_predictions function
plot_prediction_vs_ground_truth(merged_patches, "Faster RCNN with Alexnet")

# %%
import matplotlib.pyplot as plt
import numpy as np
import ternary

def plot_ternary_comparison(merged_patches, model_name):
    # Extract normalized ground truth and predicted values
    gt_clear = merged_patches['clear_norm_gt']
    gt_cloudy = merged_patches['cloudy_norm_gt']
    gt_amber = merged_patches['amber_norm_gt']
    
    pred_clear = merged_patches['clear_norm_pred']
    pred_cloudy = merged_patches['cloudy_norm_pred']
    pred_amber = merged_patches['amber_norm_pred']

    # Create the figure and axis
    fig, ax = plt.subplots(figsize=(10, 8))
    tax = ternary.TernaryAxesSubplot(ax=ax, scale=1.0)

    # Plot ground truth points
    tax.scatter([(gt_clear[i], gt_cloudy[i], gt_amber[i]) for i in range(len(gt_clear))], 
                marker='o', color='blue', label='Ground Truth', alpha=0.5)

    # Plot predicted points
    tax.scatter([(pred_clear[i], pred_cloudy[i], pred_amber[i]) for i in range(len(pred_clear))], 
                marker='s', color='red', label='Predicted', alpha=0.5)

    # Customize the plot
    tax.boundary(linewidth=2.0)
    tax.gridlines(multiple=0.1, color="gray")
    tax.set_title(f"Ternary Plot of Trichome Types for {model_name}", fontsize=12)

    # Set labels
    tax.left_axis_label("Clear", fontsize=10)
    tax.right_axis_label("Cloudy", fontsize=10)
    tax.bottom_axis_label("Amber", fontsize=10)

    # Add legend
    ax.legend(loc='best')

    # Save the plot
    plt.tight_layout()
    plt.savefig(f'ternary_plot_{model_name}.png')
    plt.close()

# %%
plot_ternary_comparison(merged_patches, "Faster RCNN with Alexnet")
# Out:
# /tmp/ipykernel_2478556/3655797617.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tax.scatter([(gt_clear[i], gt_cloudy[i], gt_amber[i]) for i in range(len(gt_clear))],
# /home/etaylor/.conda/envs/fastai_env/lib/python3.10/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
# /tmp/ipykernel_2478556/3655797617.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   tax.scatter([(pred_clear[i], pred_cloudy[i], pred_amber[i]) for i in range(len(pred_clear))],

# %%
# TODO: organize the predictions dataframes that it would be easier to compare the results
# TODO: align the format of the pred and gt dfs
# TODO: calc evaluation metrics
# TODO: add comparison for the other detection models and eval results
