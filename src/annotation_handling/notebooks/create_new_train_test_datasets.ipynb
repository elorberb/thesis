# %% [markdown]
# # Create Ground Truth Dataset
# In this notebook we are able to create updated ground truth dataset, which is built from the updated annotated data.
# We are also will split the data to train and test splits for further model fine tuning and evaluation.
# Each time we want to create a new data for the updated annotations use this notebook.

# %%
import pandas as pd
GROUND_TRUTH_METADATA_FILE = "/home/etaylor/code_projects/thesis/data/metadata/ground_truth_metadata.csv"

# %% [markdown]
# ### Option 1 - Load the ground truth dataset

# %%
# load the ground_truth_df from the csv file
ground_truth_df = pd.read_csv(GROUND_TRUTH_METADATA_FILE)
ground_truth_df.head()
# Out:
#   image_number                                         image_path  \
# 0     IMG_2198  /sise/home/etaylor/images/raw_images/week9_15_...
# 1     IMG_2153  /sise/home/etaylor/images/raw_images/week9_15_...
# 2     IMG_2145  /sise/home/etaylor/images/raw_images/week9_15_...
# 3     IMG_2129  /sise/home/etaylor/images/raw_images/week9_15_...
# 4     IMG_1875  /sise/home/etaylor/images/raw_images/week8_07_...
#
#         week_number  clear  cloudy  amber
# 0  week9_15_06_2023     48     148     10
# 1  week9_15_06_2023     38     120     28
# 2  week9_15_06_2023     51     110     61
# 3  week9_15_06_2023     75     216      9
# 4  week8_07_06_2023      7      77      9

# %% [markdown]
# ### Option 2 - Calculate the Ground Truth Dataset

# %%
import pickle
import pandas as pd
import config

#load annotated data
with open('/home/etaylor/code_projects/thesis/metadata/images_annotated.pkl', 'rb') as f:
    users_annotated_data = pickle.load(f)
    
users_annotated_df = pd.DataFrame(users_annotated_data, columns=['image_number'])
users_annotated_df.head()
# Out:
#   image_number
# 0     IMG_2129
# 1     IMG_2198
# 2     IMG_0546
# 3     IMG_1079
# 4     IMG_0543

# %%
# Get the ground truth from the annotated metadata csv
annotation_tracking_df = pd.read_csv(config.ANNOTATIONS_TRACKING_METADATA_FILE)

# filter all records where done column is True
annotation_tracking_df = annotation_tracking_df[annotation_tracking_df.done == True]
print(f"Number of records in the annotation tracking metadata file: {len(annotation_tracking_df)}")

# convert Time column to datetime from strtime
annotation_tracking_df['Time'] = pd.to_datetime(annotation_tracking_df['Time'], format='%d-%m-%Y_%H-%M-%S')

# filter all records that the image_number are in users_annotated_df or the Time is past 2024
annotation_working_df = annotation_tracking_df[annotation_tracking_df.image_number.isin(users_annotated_df.image_number) | (annotation_tracking_df.Time > '2024-01-01')]
print(f"Number of records in the annotation tracking metadata file that are also annotated by users: {len(annotation_working_df)}")
annotation_working_df.head()
# Out:
# Number of records in the annotation tracking metadata file: 55
# Number of records in the annotation tracking metadata file that are also annotated by users: 50
#   image_number annotator                Time  done
# 0     IMG_2198    dorins 2023-12-15 19:26:10  True
# 1     IMG_2153    dorins 2023-12-15 19:26:10  True
# 3     IMG_2145  Nirmalka 2023-12-15 19:26:10  True
# 4     IMG_2129  Nirmalka 2023-12-15 19:26:10  True
# 5     IMG_1875    dorins 2023-12-15 19:26:10  True

# %%
from src.annotation_handling.segmentsai_handler import SegmentsAIHandler
segments_handler = SegmentsAIHandler()

ground_truth_trichome_distribution = {}
# get the trichome distribution for each annotated image dataset
for image_number in annotation_working_df.image_number:
    print(f"get the distribution for image {image_number}")
    trichome_distribution = segments_handler.get_trichome_distribution(image_number)
    ground_truth_trichome_distribution[image_number] = trichome_distribution
    print(f"Distribution for image {image_number}: \n{trichome_distribution}")
# Out:
# INFO:segments.client:Initialized successfully.
# get the distribution for image IMG_2198
# Distribution for image IMG_2198:
# {'clear': 48, 'cloudy': 148, 'amber': 10}
# get the distribution for image IMG_2153
# Distribution for image IMG_2153:
# {'clear': 38, 'cloudy': 120, 'amber': 28}
# get the distribution for image IMG_2145
# Distribution for image IMG_2145:
# {'clear': 51, 'cloudy': 110, 'amber': 61}
# get the distribution for image IMG_2129
# Distribution for image IMG_2129:
# {'clear': 75, 'cloudy': 216, 'amber': 9}
# get the distribution for image IMG_1875
# Distribution for image IMG_1875:
# {'clear': 7, 'cloudy': 77, 'amber': 9}
# get the distribution for image IMG_1787
# Distribution for image IMG_1787:
# {'clear': 3, 'cloudy': 104, 'amber': 60}
# get the distribution for image IMG_1857
# Distribution for image IMG_1857:
# {'clear': 7, 'cloudy': 163, 'amber': 17}
# get the distribution for image IMG_1753
# Distribution for image IMG_1753:
# {'clear': 74, 'cloudy': 21, 'amber': 0}
# get the distribution for image IMG_1818
# Distribution for image IMG_1818:
# {'clear': 17, 'cloudy': 197, 'amber': 25}
# get the distribution for image IMG_0014
# Distribution for image IMG_0014:
# {'clear': 56, 'cloudy': 54, 'amber': 1}
# get the distribution for image IMG_0003
# Distribution for image IMG_0003:
# {'clear': 130, 'cloudy': 61, 'amber': 0}
# get the distribution for image IMG_0001
# Distribution for image IMG_0001:
# {'clear': 83, 'cloudy': 140, 'amber': 1}
# get the distribution for image IMG_1093
# Distribution for image IMG_1093:
# {'clear': 33, 'cloudy': 143, 'amber': 36}
# get the distribution for image IMG_1085
# Distribution for image IMG_1085:
# {'clear': 9, 'cloudy': 136, 'amber': 5}
# get the distribution for image IMG_1079
# Distribution for image IMG_1079:
# {'clear': 68, 'cloudy': 79, 'amber': 6}
# get the distribution for image IMG_1082
# Distribution for image IMG_1082:
# {'clear': 10, 'cloudy': 86, 'amber': 1}
# get the distribution for image IMG_0016
# Distribution for image IMG_0016:
# {'clear': 77, 'cloudy': 38, 'amber': 0}
# get the distribution for image IMG_0017
# Distribution for image IMG_0017:
# {'clear': 106, 'cloudy': 59, 'amber': 3}
# get the distribution for image IMG_0540
# Distribution for image IMG_0540:
# {'clear': 91, 'cloudy': 54, 'amber': 0}
# get the distribution for image IMG_0542
# Distribution for image IMG_0542:
# {'clear': 36, 'cloudy': 49, 'amber': 0}
# get the distribution for image IMG_0543
# Distribution for image IMG_0543:
# {'clear': 79, 'cloudy': 167, 'amber': 0}
# get the distribution for image IMG_0545
# Distribution for image IMG_0545:
# {'clear': 81, 'cloudy': 74, 'amber': 2}
# get the distribution for image IMG_0546
# Distribution for image IMG_0546:
# {'clear': 25, 'cloudy': 78, 'amber': 2}
# get the distribution for image IMG_0547
# Distribution for image IMG_0547:
# {'clear': 117, 'cloudy': 264, 'amber': 4}
# get the distribution for image IMG_2242
# Distribution for image IMG_2242:
# {'clear': 0, 'cloudy': 35, 'amber': 36}
# get the distribution for image IMG_2285
# Distribution for image IMG_2285:
# {'clear': 30, 'cloudy': 128, 'amber': 12}
# get the distribution for image IMG_2276
# Distribution for image IMG_2276:
# {'clear': 19, 'cloudy': 112, 'amber': 10}
# get the distribution for image IMG_1182
# Distribution for image IMG_1182:
# {'clear': 14, 'cloudy': 65, 'amber': 5}
# get the distribution for image IMG_0581
# Distribution for image IMG_0581:
# {'clear': 97, 'cloudy': 151, 'amber': 0}
# get the distribution for image IMG_2271
# Distribution for image IMG_2271:
# {'clear': 23, 'cloudy': 58, 'amber': 12}
# get the distribution for image IMG_2235
# Distribution for image IMG_2235:
# {'clear': 1, 'cloudy': 42, 'amber': 43}
# get the distribution for image IMG_1144
# Distribution for image IMG_1144:
# {'clear': 6, 'cloudy': 72, 'amber': 0}
# get the distribution for image IMG_0048
# Distribution for image IMG_0048:
# {'clear': 33, 'cloudy': 131, 'amber': 1}
# get the distribution for image IMG_2167
# Distribution for image IMG_2167:
# {'clear': 4, 'cloudy': 35, 'amber': 19}
# get the distribution for image IMG_2163
# Distribution for image IMG_2163:
# {'clear': 14, 'cloudy': 59, 'amber': 24}
# get the distribution for image IMG_1111
# Distribution for image IMG_1111:
# {'clear': 59, 'cloudy': 57, 'amber': 2}
# get the distribution for image IMG_1096
# Distribution for image IMG_1096:
# {'clear': 30, 'cloudy': 121, 'amber': 39}
# get the distribution for image IMG_9998
# Distribution for image IMG_9998:
# {'clear': 109, 'cloudy': 80, 'amber': 0}
# get the distribution for image IMG_2134
# Distribution for image IMG_2134:
# {'clear': 35, 'cloudy': 87, 'amber': 7}
# get the distribution for image IMG_2157
# Distribution for image IMG_2157:
# {'clear': 9, 'cloudy': 73, 'amber': 42}
# get the distribution for image IMG_1186
# Distribution for image IMG_1186:
# {'clear': 65, 'cloudy': 27, 'amber': 1}
# get the distribution for image IMG_0612
# Distribution for image IMG_0612:
# {'clear': 94, 'cloudy': 111, 'amber': 1}
# get the distribution for image IMG_0045
# Distribution for image IMG_0045:
# {'clear': 119, 'cloudy': 100, 'amber': 8}
# get the distribution for image IMG_0019
# Distribution for image IMG_0019:
# {'clear': 144, 'cloudy': 100, 'amber': 4}
# get the distribution for image IMG_0562
# Distribution for image IMG_0562:
# {'clear': 5, 'cloudy': 41, 'amber': 4}
# get the distribution for image IMG_0572
# Distribution for image IMG_0572:
# {'clear': 79, 'cloudy': 65, 'amber': 3}
# get the distribution for image IMG_1784
# Distribution for image IMG_1784:
# {'clear': 130, 'cloudy': 60, 'amber': 4}
# get the distribution for image IMG_0058
# Distribution for image IMG_0058:
# {'clear': 78, 'cloudy': 31, 'amber': 0}
# get the distribution for image IMG_0597
# Distribution for image IMG_0597:
# {'clear': 27, 'cloudy': 7, 'amber': 0}
# get the distribution for image IMG_1827
# Distribution for image IMG_1827:
# {'clear': 43, 'cloudy': 63, 'amber': 18}

# %%
# organize the ground truth to a df
images_annotations = []
# create a csv file for each image path and the trichome value
for image_number, image_dist in ground_truth_trichome_distribution.items():
    image_path = config.get_image_path(image_number)
    week, zoom_type = config.find_image_details(image_number)
    images_annotations.append({"image_number": image_number,
                                "image_path":image_path,
                                "week_number": week,
                                "clear": image_dist.get("clear", 0),
                                "cloudy": image_dist.get("cloudy", 0),
                                "amber": image_dist.get("amber", 0)})
ground_truth_df = pd.DataFrame(images_annotations)

# save the ground_truth_df to a csv file with timestamp
ground_truth_df.to_csv(GROUND_TRUTH_METADATA_FILE, index=False)

ground_truth_df.head()
# Out:
#   image_number                                         image_path  \
# 0     IMG_2198  /sise/home/etaylor/images/raw_images/week9_15_...
# 1     IMG_2153  /sise/home/etaylor/images/raw_images/week9_15_...
# 2     IMG_2145  /sise/home/etaylor/images/raw_images/week9_15_...
# 3     IMG_2129  /sise/home/etaylor/images/raw_images/week9_15_...
# 4     IMG_1875  /sise/home/etaylor/images/raw_images/week8_07_...
#
#         week_number  clear  cloudy  amber
# 0  week9_15_06_2023     48     148     10
# 1  week9_15_06_2023     38     120     28
# 2  week9_15_06_2023     51     110     61
# 3  week9_15_06_2023     75     216      9
# 4  week8_07_06_2023      7      77      9

# %% [markdown]
# ### Ground Truth Data Stats

# %%
ground_truth_df['week_number'].value_counts()
# Out:
# week_number
# week9_15_06_2023    13
# week6_22_05_2023    11
# week5_18_05_2023    10
# week7_01_06_2023     9
# week8_07_06_2023     7
# Name: count, dtype: int64

# %% [markdown]
# ## Split data to train and test
# Prepare the data for all the models that each would be trained and evaluated on the same data.

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets
train_df, test_df = train_test_split(ground_truth_df, test_size=0.2, random_state=314977596)  # 20% data as test set

# %%
print(f"Number of records in the train set: {len(train_df)}")
print(f"Weeks distribution in the train set: \n{train_df['week_number'].value_counts()}")
train_df.head()
# Out:
# Number of records in the train set: 40
# Weeks distribution in the train set:
# week_number
# week6_22_05_2023    10
# week9_15_06_2023    10
# week5_18_05_2023     8
# week8_07_06_2023     6
# week7_01_06_2023     6
# Name: count, dtype: int64
#    image_number                                         image_path  \
# 48     IMG_0597  /sise/home/etaylor/images/raw_images/week6_22_...
# 34     IMG_2163  /sise/home/etaylor/images/raw_images/week9_15_...
# 45     IMG_0572  /sise/home/etaylor/images/raw_images/week6_22_...
# 3      IMG_2129  /sise/home/etaylor/images/raw_images/week9_15_...
# 1      IMG_2153  /sise/home/etaylor/images/raw_images/week9_15_...
#
#          week_number  clear  cloudy  amber
# 48  week6_22_05_2023     27       7      0
# 34  week9_15_06_2023     14      59     24
# 45  week6_22_05_2023     79      65      3
# 3   week9_15_06_2023     75     216      9
# 1   week9_15_06_2023     38     120     28

# %%
print(f"Number of records in the test set: {len(test_df)}")
print(f"Weeks distribution in the test set: \n{test_df['week_number'].value_counts()}")
test_df.head()
# Out:
# Number of records in the test set: 10
# Weeks distribution in the test set:
# week_number
# week9_15_06_2023    3
# week7_01_06_2023    3
# week5_18_05_2023    2
# week6_22_05_2023    1
# week8_07_06_2023    1
# Name: count, dtype: int64
#    image_number                                         image_path  \
# 19     IMG_0542  /sise/home/etaylor/images/raw_images/week6_22_...
# 0      IMG_2198  /sise/home/etaylor/images/raw_images/week9_15_...
# 7      IMG_1753  /sise/home/etaylor/images/raw_images/week8_07_...
# 12     IMG_1093  /sise/home/etaylor/images/raw_images/week7_01_...
# 43     IMG_0019  /sise/home/etaylor/images/raw_images/week5_18_...
#
#          week_number  clear  cloudy  amber
# 19  week6_22_05_2023     36      49      0
# 0   week9_15_06_2023     48     148     10
# 7   week8_07_06_2023     74      21      0
# 12  week7_01_06_2023     33     143     36
# 43  week5_18_05_2023    144     100      4

# %% [markdown]
# Save the train and test data

# %%
import config
# save the train data
train_df_path = f"/home/etaylor/code_projects/thesis/data/train_data_{config.get_datetime_str()}.csv"
train_df.to_csv(train_df_path, index=False)

# save the test data
test_df_path = f"/home/etaylor/code_projects/thesis/data/test_data_{config.get_datetime_str()}.csv"
test_df.to_csv(test_df_path, index=False)

# %% [markdown]
# ### Create the new datasets in SegmentAI

# %%
from datetime import datetime

# %% [markdown]
# Create the new train and test datasets

# %%
zoom_type = '3x_regular'
# add datetime obj
current_date = datetime.now().strftime(config.DATETIME_STR_FORMAT)

train_image_numbers_str = ", ".join([str(image_number) for image_number in train_df['image_number'].values])

dataset_name_train = f"cannabis_patches_train_{current_date}"
description_train = (
    f"Train set for images {train_image_numbers_str}."
)
task_type = "segmentation-bitmap"

task_attributes = {
    "format_version": "0.1",
    "categories": [{"name": "trichome", "id": 0, "color": [65,117,5]},
                {"name": "clear", "id": 1, "color": [155,155,155]},
                {"name": "cloudy", "id": 2, "color": [255,255,255]},
                {"name": "amber", "id": 3, "color": [245,166,35]}]
}

# Create the train dataset:
train_dataset_instance = segments_handler.create_new_dataset(dataset_name_train, description_train, task_type, task_attributes)
print(train_dataset_instance)

test_image_numbers_str = ", ".join([str(image_number) for image_number in test_df['image_number'].values])

dataset_name_test = f"cannabis_patches_test_{current_date}"
description_test = (
    f"Test set for images {test_image_numbers_str}."
)

# Create the test dataset:
dataset_instance_test = segments_handler.create_new_dataset(dataset_name_test, description_test, task_type, task_attributes)
print(dataset_instance_test)
# Out:
# name='cannabis_patches_train_26-04-2024_15-44-44' full_name='etaylor/cannabis_patches_train_26-04-2024_15-44-44' cloned_from=None description='Train set for images IMG_0597, IMG_2163, IMG_0572, IMG_2129, IMG_2153, IMG_2235, IMG_1787, IMG_0014, IMG_0045, IMG_0612, IMG_0003, IMG_1144, IMG_2157, IMG_0048, IMG_1186, IMG_0017, IMG_0016, IMG_0543, IMG_2167, IMG_2276, IMG_0547, IMG_1857, IMG_0562, IMG_1082, IMG_2134, IMG_9998, IMG_0581, IMG_1085, IMG_1827, IMG_1182, IMG_2145, IMG_0540, IMG_0546, IMG_2242, IMG_0001, IMG_0545, IMG_1784, IMG_1875, IMG_1111, IMG_1818.' category='other' public=False owner=Owner(username='etaylor', created_at='2022-12-28T12:53:18Z', email=None) created_at='2024-04-26T12:44:45.218197Z' enable_ratings=False enable_skip_labeling=True enable_skip_reviewing=False enable_save_button=False enable_label_status_verified=False enable_same_dimensions_track_constraint=False enable_interpolation=True task_type='segmentation-bitmap' label_stats=LabelStats(REVIEWED=None, REVIEWING_IN_PROGRESS=None, LABELED=None, LABELING_IN_PROGRESS=None, REJECTED=None, PRELABELED=None, SKIPPED=None, VERIFIED=None, UNLABELED=None, TOTAL=None) labeling_inactivity_timeout_seconds=300 samples_count=0 collaborators_count=None task_attributes=TaskAttributes(format_version='0.1', categories=[TaskAttributeCategory(name='trichome', id=0, color=(65, 117, 5), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='clear', id=1, color=(155, 155, 155), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='cloudy', id=2, color=(255, 255, 255), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='amber', id=3, color=(245, 166, 35), has_instances=None, attributes=None, dimensions=None)], image_attributes=None) labelsets=None role=None readme='' metadata={} noncollaborator_can_label=False noncollaborator_can_review=False insights_urls=None embeddings_enabled=None
# name='cannabis_patches_test_26-04-2024_15-44-44' full_name='etaylor/cannabis_patches_test_26-04-2024_15-44-44' cloned_from=None description='Test set for images IMG_0542, IMG_2198, IMG_1753, IMG_1093, IMG_0019, IMG_1096, IMG_2271, IMG_2285, IMG_1079, IMG_0058.' category='other' public=False owner=Owner(username='etaylor', created_at='2022-12-28T12:53:18Z', email=None) created_at='2024-04-26T12:44:45.355281Z' enable_ratings=False enable_skip_labeling=True enable_skip_reviewing=False enable_save_button=False enable_label_status_verified=False enable_same_dimensions_track_constraint=False enable_interpolation=True task_type='segmentation-bitmap' label_stats=LabelStats(REVIEWED=None, REVIEWING_IN_PROGRESS=None, LABELED=None, LABELING_IN_PROGRESS=None, REJECTED=None, PRELABELED=None, SKIPPED=None, VERIFIED=None, UNLABELED=None, TOTAL=None) labeling_inactivity_timeout_seconds=300 samples_count=0 collaborators_count=None task_attributes=TaskAttributes(format_version='0.1', categories=[TaskAttributeCategory(name='trichome', id=0, color=(65, 117, 5), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='clear', id=1, color=(155, 155, 155), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='cloudy', id=2, color=(255, 255, 255), has_instances=None, attributes=None, dimensions=None), TaskAttributeCategory(name='amber', id=3, color=(245, 166, 35), has_instances=None, attributes=None, dimensions=None)], image_attributes=None) labelsets=None role=None readme='' metadata={} noncollaborator_can_label=False noncollaborator_can_review=False insights_urls=None embeddings_enabled=None

# %% [markdown]
# Add the images for the train and test

# %%
# add the images to the train dataset
train_dataset_identifier = f"etaylor/{dataset_name_train}"
for index, row in train_df.iterrows():
    image_number = row["image_number"]
    week, zoom_type = config.find_image_details(image_number)
    dataset_identifier = segments_handler.get_segments_dataset_identifier(image_number, week, zoom_type)
    segments_handler.copy_dataset_contents(dataset_identifier, train_dataset_identifier, verbose=True, only_patches=True)
# Out:
# Skipping raw image IMG_0597.JPG
# Processing sample 2: IMG_0597_p0.png
#   - Copied sample IMG_0597_p0.png and its label.
# Processing sample 3: IMG_0597_p1.png
#   - Copied sample IMG_0597_p1.png and its label.
# Processing sample 4: IMG_0597_p2.png
#   - Copied sample IMG_0597_p2.png and its label.
# Processing sample 5: IMG_0597_p3.png
#   - Copied sample IMG_0597_p3.png and its label.
# Processing sample 6: IMG_0597_p4.png
#   - Copied sample IMG_0597_p4.png and its label.
# Processing sample 7: IMG_0597_p5.png
#   - Copied sample IMG_0597_p5.png and its label.
# Processing sample 8: IMG_0597_p6.png
#   - Copied sample IMG_0597_p6.png and its label.
# Skipping sample IMG_0597_p7.png due to label status mismatch
# Processing sample 10: IMG_0597_p8.png
#   - Copied sample IMG_0597_p8.png and its label.
# Skipping sample IMG_0597_p9.png due to label status mismatch
# Skipping raw image IMG_2163.JPG
# Processing sample 2: IMG_2163_p0.png
#   - Copied sample IMG_2163_p0.png and its label.
# Processing sample 3: IMG_2163_p1.png
#   - Copied sample IMG_2163_p1.png and its label.
# Processing sample 4: IMG_2163_p2.png
#   - Copied sample IMG_2163_p2.png and its label.
# Processing sample 5: IMG_2163_p3.png
#   - Copied sample IMG_2163_p3.png and its label.
# Processing sample 6: IMG_2163_p4.png
#   - Copied sample IMG_2163_p4.png and its label.
# Processing sample 7: IMG_2163_p5.png
#   - Copied sample IMG_2163_p5.png and its label.
# Processing sample 8: IMG_2163_p6.png
#   - Copied sample IMG_2163_p6.png and its label.
# Processing sample 9: IMG_2163_p7.png
#   - Copied sample IMG_2163_p7.png and its label.
# Processing sample 10: IMG_2163_p8.png
#   - Copied sample IMG_2163_p8.png and its label.
# Skipping raw image IMG_0572.JPG
# Processing sample 2: IMG_0572_p0.png
#   - Copied sample IMG_0572_p0.png and its label.
# Processing sample 3: IMG_0572_p10.png
#   - Copied sample IMG_0572_p10.png and its label.
# Processing sample 4: IMG_0572_p11.png
#   - Copied sample IMG_0572_p11.png and its label.
# Processing sample 5: IMG_0572_p1.png
#   - Copied sample IMG_0572_p1.png and its label.
# Processing sample 6: IMG_0572_p2.png
#   - Copied sample IMG_0572_p2.png and its label.
# Processing sample 7: IMG_0572_p3.png
#   - Copied sample IMG_0572_p3.png and its label.
# Processing sample 8: IMG_0572_p4.png
#   - Copied sample IMG_0572_p4.png and its label.
# Processing sample 9: IMG_0572_p5.png
#   - Copied sample IMG_0572_p5.png and its label.
# Processing sample 10: IMG_0572_p6.png
#   - Copied sample IMG_0572_p6.png and its label.
# Processing sample 11: IMG_0572_p7.png
#   - Copied sample IMG_0572_p7.png and its label.
# Processing sample 12: IMG_0572_p8.png
#   - Copied sample IMG_0572_p8.png and its label.
# Processing sample 13: IMG_0572_p9.png
#   - Copied sample IMG_0572_p9.png and its label.
# Skipping raw image IMG_2129.JPG
# Processing sample 2: IMG_2129_p0.png
#   - Copied sample IMG_2129_p0.png and its label.
# Processing sample 3: IMG_2129_p10.png
#   - Copied sample IMG_2129_p10.png and its label.
# Processing sample 4: IMG_2129_p1.png
#   - Copied sample IMG_2129_p1.png and its label.
# Skipping sample IMG_2129_p2.png due to label status mismatch
# Processing sample 6: IMG_2129_p3.png
#   - Copied sample IMG_2129_p3.png and its label.
# Skipping sample IMG_2129_p4.png due to label status mismatch
# Processing sample 8: IMG_2129_p5.png
#   - Copied sample IMG_2129_p5.png and its label.
# Processing sample 9: IMG_2129_p6.png
#   - Copied sample IMG_2129_p6.png and its label.
# Processing sample 10: IMG_2129_p7.png
#   - Copied sample IMG_2129_p7.png and its label.
# Processing sample 11: IMG_2129_p8.png
#   - Copied sample IMG_2129_p8.png and its label.
# Processing sample 12: IMG_2129_p9.png
#   - Copied sample IMG_2129_p9.png and its label.
# Skipping raw image IMG_2153.JPG
# Processing sample 2: IMG_2153_p0.png
#   - Copied sample IMG_2153_p0.png and its label.
# Processing sample 3: IMG_2153_p10.png
#   - Copied sample IMG_2153_p10.png and its label.
# Processing sample 4: IMG_2153_p2.png
#   - Copied sample IMG_2153_p2.png and its label.
# Processing sample 5: IMG_2153_p3.png
#   - Copied sample IMG_2153_p3.png and its label.
# Processing sample 6: IMG_2153_p4.png
#   - Copied sample IMG_2153_p4.png and its label.
# Processing sample 7: IMG_2153_p5.png
#   - Copied sample IMG_2153_p5.png and its label.
# Processing sample 8: IMG_2153_p6.png
#   - Copied sample IMG_2153_p6.png and its label.
# Processing sample 9: IMG_2153_p7.png
#   - Copied sample IMG_2153_p7.png and its label.
# Processing sample 10: IMG_2153_p8.png
#   - Copied sample IMG_2153_p8.png and its label.
# Processing sample 11: IMG_2153_p9.png
#   - Copied sample IMG_2153_p9.png and its label.
# Skipping raw image IMG_2235.JPG
# Processing sample 2: IMG_2235_p0.png
#   - Copied sample IMG_2235_p0.png and its label.
# Processing sample 3: IMG_2235_p1.png
#   - Copied sample IMG_2235_p1.png and its label.
# Processing sample 4: IMG_2235_p2.png
#   - Copied sample IMG_2235_p2.png and its label.
# Processing sample 5: IMG_2235_p3.png
#   - Copied sample IMG_2235_p3.png and its label.
# Processing sample 6: IMG_2235_p4.png
#   - Copied sample IMG_2235_p4.png and its label.
# Processing sample 7: IMG_2235_p5.png
#   - Copied sample IMG_2235_p5.png and its label.
# Processing sample 8: IMG_2235_p6.png
#   - Copied sample IMG_2235_p6.png and its label.
# Processing sample 9: IMG_2235_p7.png
#   - Copied sample IMG_2235_p7.png and its label.
# Skipping raw image IMG_1787.JPG
# Skipping sample IMG_1787_p0.png due to label status mismatch
# Skipping sample IMG_1787_p10.png due to label status mismatch
# Processing sample 4: IMG_1787_p11.png
#   - Copied sample IMG_1787_p11.png and its label.
# Skipping sample IMG_1787_p12.png due to label status mismatch
# Processing sample 6: IMG_1787_p1.png
#   - Copied sample IMG_1787_p1.png and its label.
# Processing sample 7: IMG_1787_p2.png
#   - Copied sample IMG_1787_p2.png and its label.
# Processing sample 8: IMG_1787_p3.png
#   - Copied sample IMG_1787_p3.png and its label.
# Processing sample 9: IMG_1787_p4.png
#   - Copied sample IMG_1787_p4.png and its label.
# Skipping sample IMG_1787_p5.png due to label status mismatch
# Processing sample 11: IMG_1787_p6.png
#   - Copied sample IMG_1787_p6.png and its label.
# Processing sample 12: IMG_1787_p7.png
#   - Copied sample IMG_1787_p7.png and its label.
# Processing sample 13: IMG_1787_p8.png
#   - Copied sample IMG_1787_p8.png and its label.
# Skipping sample IMG_1787_p9.png due to label status mismatch
# Skipping raw image IMG_0014.JPG
# Processing sample 2: IMG_0014_p0.png
#   - Copied sample IMG_0014_p0.png and its label.
# Processing sample 3: IMG_0014_p1.png
#   - Copied sample IMG_0014_p1.png and its label.
# Processing sample 4: IMG_0014_p2.png
#   - Copied sample IMG_0014_p2.png and its label.
# Processing sample 5: IMG_0014_p3.png
#   - Copied sample IMG_0014_p3.png and its label.
# Processing sample 6: IMG_0014_p4.png
#   - Copied sample IMG_0014_p4.png and its label.
# Processing sample 7: IMG_0014_p5.png
#   - Copied sample IMG_0014_p5.png and its label.
# Processing sample 8: IMG_0014_p6.png
#   - Copied sample IMG_0014_p6.png and its label.
# Processing sample 9: IMG_0014_p7.png
#   - Copied sample IMG_0014_p7.png and its label.
# Skipping raw image IMG_0045.JPG
# Processing sample 2: IMG_0045_p0.png
#   - Copied sample IMG_0045_p0.png and its label.
# Processing sample 3: IMG_0045_p10.png
#   - Copied sample IMG_0045_p10.png and its label.
# Processing sample 4: IMG_0045_p11.png
#   - Copied sample IMG_0045_p11.png and its label.
# Processing sample 5: IMG_0045_p12.png
#   - Copied sample IMG_0045_p12.png and its label.
# Processing sample 6: IMG_0045_p13.png
#   - Copied sample IMG_0045_p13.png and its label.
# Processing sample 7: IMG_0045_p14.png
#   - Copied sample IMG_0045_p14.png and its label.
# Processing sample 8: IMG_0045_p15.png
#   - Copied sample IMG_0045_p15.png and its label.
# Processing sample 9: IMG_0045_p1.png
#   - Copied sample IMG_0045_p1.png and its label.
# Processing sample 10: IMG_0045_p2.png
#   - Copied sample IMG_0045_p2.png and its label.
# Processing sample 11: IMG_0045_p3.png
#   - Copied sample IMG_0045_p3.png and its label.
# Processing sample 12: IMG_0045_p4.png
#   - Copied sample IMG_0045_p4.png and its label.
# Processing sample 13: IMG_0045_p5.png
#   - Copied sample IMG_0045_p5.png and its label.
# Processing sample 14: IMG_0045_p6.png
#   - Copied sample IMG_0045_p6.png and its label.
# Processing sample 15: IMG_0045_p7.png
#   - Copied sample IMG_0045_p7.png and its label.
# Processing sample 16: IMG_0045_p8.png
#   - Copied sample IMG_0045_p8.png and its label.
# Processing sample 17: IMG_0045_p9.png
#   - Copied sample IMG_0045_p9.png and its label.
# Skipping raw image IMG_0612.JPG
# Skipping sample IMG_0612_p0.png due to label status mismatch
# Processing sample 3: IMG_0612_p10.png
#   - Copied sample IMG_0612_p10.png and its label.
# Processing sample 4: IMG_0612_p11.png
#   - Copied sample IMG_0612_p11.png and its label.
# Processing sample 5: IMG_0612_p12.png
#   - Copied sample IMG_0612_p12.png and its label.
# Processing sample 6: IMG_0612_p1.png
#   - Copied sample IMG_0612_p1.png and its label.
# Processing sample 7: IMG_0612_p2.png
#   - Copied sample IMG_0612_p2.png and its label.
# Processing sample 8: IMG_0612_p3.png
#   - Copied sample IMG_0612_p3.png and its label.
# Processing sample 9: IMG_0612_p4.png
#   - Copied sample IMG_0612_p4.png and its label.
# Processing sample 10: IMG_0612_p5.png
#   - Copied sample IMG_0612_p5.png and its label.
# Processing sample 11: IMG_0612_p6.png
#   - Copied sample IMG_0612_p6.png and its label.
# Processing sample 12: IMG_0612_p7.png
#   - Copied sample IMG_0612_p7.png and its label.
# Processing sample 13: IMG_0612_p8.png
#   - Copied sample IMG_0612_p8.png and its label.
# Processing sample 14: IMG_0612_p9.png
#   - Copied sample IMG_0612_p9.png and its label.
# Skipping raw image IMG_0003.JPG
# Skipping sample IMG_0003_p0.png due to label status mismatch
# Processing sample 3: IMG_0003_p10.png
#   - Copied sample IMG_0003_p10.png and its label.
# Skipping sample IMG_0003_p1.png due to label status mismatch
# Processing sample 5: IMG_0003_p2.png
#   - Copied sample IMG_0003_p2.png and its label.
# Processing sample 6: IMG_0003_p3.png
#   - Copied sample IMG_0003_p3.png and its label.
# Processing sample 7: IMG_0003_p4.png
#   - Copied sample IMG_0003_p4.png and its label.
# Processing sample 8: IMG_0003_p5.png
#   - Copied sample IMG_0003_p5.png and its label.
# Processing sample 9: IMG_0003_p6.png
#   - Copied sample IMG_0003_p6.png and its label.
# Processing sample 10: IMG_0003_p7.png
#   - Copied sample IMG_0003_p7.png and its label.
# Processing sample 11: IMG_0003_p8.png
#   - Copied sample IMG_0003_p8.png and its label.
# Processing sample 12: IMG_0003_p9.png
#   - Copied sample IMG_0003_p9.png and its label.
# Skipping raw image IMG_1144.JPG
# Skipping sample IMG_1144_p0.png due to label status mismatch
# Skipping sample IMG_1144_p10.png due to label status mismatch
# Processing sample 4: IMG_1144_p11.png
#   - Copied sample IMG_1144_p11.png and its label.
# Skipping sample IMG_1144_p12.png due to label status mismatch
# Skipping sample IMG_1144_p13.png due to label status mismatch
# Skipping sample IMG_1144_p1.png due to label status mismatch
# Skipping sample IMG_1144_p2.png due to label status mismatch
# Skipping sample IMG_1144_p3.png due to label status mismatch
# Skipping sample IMG_1144_p4.png due to label status mismatch
# Skipping sample IMG_1144_p5.png due to label status mismatch
# Skipping sample IMG_1144_p6.png due to label status mismatch
# Skipping sample IMG_1144_p7.png due to label status mismatch
# Processing sample 14: IMG_1144_p8.png
#   - Copied sample IMG_1144_p8.png and its label.
# Processing sample 15: IMG_1144_p9.png
#   - Copied sample IMG_1144_p9.png and its label.
# Skipping raw image IMG_2157.JPG
# Processing sample 2: IMG_2157_p0.png
#   - Copied sample IMG_2157_p0.png and its label.
# Processing sample 3: IMG_2157_p10.png
#   - Copied sample IMG_2157_p10.png and its label.
# Processing sample 4: IMG_2157_p1.png
#   - Copied sample IMG_2157_p1.png and its label.
# Processing sample 5: IMG_2157_p2.png
#   - Copied sample IMG_2157_p2.png and its label.
# Processing sample 6: IMG_2157_p3.png
#   - Copied sample IMG_2157_p3.png and its label.
# Processing sample 7: IMG_2157_p4.png
#   - Copied sample IMG_2157_p4.png and its label.
# Processing sample 8: IMG_2157_p5.png
#   - Copied sample IMG_2157_p5.png and its label.
# Processing sample 9: IMG_2157_p6.png
#   - Copied sample IMG_2157_p6.png and its label.
# Processing sample 10: IMG_2157_p7.png
#   - Copied sample IMG_2157_p7.png and its label.
# Processing sample 11: IMG_2157_p8.png
#   - Copied sample IMG_2157_p8.png and its label.
# Processing sample 12: IMG_2157_p9.png
#   - Copied sample IMG_2157_p9.png and its label.
# Skipping raw image IMG_0048.JPG
# Processing sample 2: IMG_0048_p0.png
#   - Copied sample IMG_0048_p0.png and its label.
# Skipping sample IMG_0048_p1.png due to label status mismatch
# Processing sample 4: IMG_0048_p2.png
#   - Copied sample IMG_0048_p2.png and its label.
# Processing sample 5: IMG_0048_p3.png
#   - Copied sample IMG_0048_p3.png and its label.
# Processing sample 6: IMG_0048_p4.png
#   - Copied sample IMG_0048_p4.png and its label.
# Processing sample 7: IMG_0048_p5.png
#   - Copied sample IMG_0048_p5.png and its label.
# Processing sample 8: IMG_0048_p6.png
#   - Copied sample IMG_0048_p6.png and its label.
# Processing sample 9: IMG_0048_p7.png
#   - Copied sample IMG_0048_p7.png and its label.
# Processing sample 10: IMG_0048_p8.png
#   - Copied sample IMG_0048_p8.png and its label.
# Skipping raw image IMG_1186.JPG
# Processing sample 2: IMG_1186_p0.png
#   - Copied sample IMG_1186_p0.png and its label.
# Processing sample 3: IMG_1186_p10.png
#   - Copied sample IMG_1186_p10.png and its label.
# Processing sample 4: IMG_1186_p1.png
#   - Copied sample IMG_1186_p1.png and its label.
# Processing sample 5: IMG_1186_p2.png
#   - Copied sample IMG_1186_p2.png and its label.
# Processing sample 6: IMG_1186_p3.png
#   - Copied sample IMG_1186_p3.png and its label.
# Processing sample 7: IMG_1186_p4.png
#   - Copied sample IMG_1186_p4.png and its label.
# Processing sample 8: IMG_1186_p5.png
#   - Copied sample IMG_1186_p5.png and its label.
# Processing sample 9: IMG_1186_p6.png
#   - Copied sample IMG_1186_p6.png and its label.
# Processing sample 10: IMG_1186_p7.png
#   - Copied sample IMG_1186_p7.png and its label.
# Processing sample 11: IMG_1186_p8.png
#   - Copied sample IMG_1186_p8.png and its label.
# Processing sample 12: IMG_1186_p9.png
#   - Copied sample IMG_1186_p9.png and its label.
# Skipping raw image IMG_0017.JPG
# Processing sample 2: IMG_0017_p0.png
#   - Copied sample IMG_0017_p0.png and its label.
# Processing sample 3: IMG_0017_p1.png
#   - Copied sample IMG_0017_p1.png and its label.
# Skipping sample IMG_0017_p2.png due to label status mismatch
# Processing sample 5: IMG_0017_p3.png
#   - Copied sample IMG_0017_p3.png and its label.
# Processing sample 6: IMG_0017_p4.png
#   - Copied sample IMG_0017_p4.png and its label.
# Processing sample 7: IMG_0017_p5.png
#   - Copied sample IMG_0017_p5.png and its label.
# Skipping sample IMG_0017_p6.png due to label status mismatch
# Processing sample 9: IMG_0017_p7.png
#   - Copied sample IMG_0017_p7.png and its label.
# Processing sample 10: IMG_0017_p8.png
#   - Copied sample IMG_0017_p8.png and its label.
# Processing sample 11: IMG_0017_p9.png
#   - Copied sample IMG_0017_p9.png and its label.
# Skipping raw image IMG_0016.JPG
# Skipping sample IMG_0016_p0.png due to label status mismatch
# Processing sample 3: IMG_0016_p1.png
#   - Copied sample IMG_0016_p1.png and its label.
# Processing sample 4: IMG_0016_p2.png
#   - Copied sample IMG_0016_p2.png and its label.
# Processing sample 5: IMG_0016_p3.png
#   - Copied sample IMG_0016_p3.png and its label.
# Processing sample 6: IMG_0016_p4.png
#   - Copied sample IMG_0016_p4.png and its label.
# Processing sample 7: IMG_0016_p5.png
#   - Copied sample IMG_0016_p5.png and its label.
# Skipping sample IMG_0016_p6.png due to label status mismatch
# Skipping sample IMG_0016_p7.png due to label status mismatch
# Processing sample 10: IMG_0016_p8.png
#   - Copied sample IMG_0016_p8.png and its label.
# Processing sample 11: IMG_0016_p9.png
#   - Copied sample IMG_0016_p9.png and its label.
# Skipping raw image IMG_0543.JPG
# Processing sample 2: IMG_0543_p0.png
#   - Copied sample IMG_0543_p0.png and its label.
# Skipping sample IMG_0543_p10.png due to label status mismatch
# Processing sample 4: IMG_0543_p11.png
#   - Copied sample IMG_0543_p11.png and its label.
# Processing sample 5: IMG_0543_p1.png
#   - Copied sample IMG_0543_p1.png and its label.
# Processing sample 6: IMG_0543_p2.png
#   - Copied sample IMG_0543_p2.png and its label.
# Processing sample 7: IMG_0543_p3.png
#   - Copied sample IMG_0543_p3.png and its label.
# Processing sample 8: IMG_0543_p4.png
#   - Copied sample IMG_0543_p4.png and its label.
# Processing sample 9: IMG_0543_p5.png
#   - Copied sample IMG_0543_p5.png and its label.
# Processing sample 10: IMG_0543_p6.png
#   - Copied sample IMG_0543_p6.png and its label.
# Processing sample 11: IMG_0543_p7.png
#   - Copied sample IMG_0543_p7.png and its label.
# Processing sample 12: IMG_0543_p8.png
#   - Copied sample IMG_0543_p8.png and its label.
# Processing sample 13: IMG_0543_p9.png
#   - Copied sample IMG_0543_p9.png and its label.
# Skipping raw image IMG_2167.JPG
# Processing sample 2: IMG_2167_p0.png
#   - Copied sample IMG_2167_p0.png and its label.
# Processing sample 3: IMG_2167_p10.png
#   - Copied sample IMG_2167_p10.png and its label.
# Processing sample 4: IMG_2167_p11.png
#   - Copied sample IMG_2167_p11.png and its label.
# Processing sample 5: IMG_2167_p1.png
#   - Copied sample IMG_2167_p1.png and its label.
# Processing sample 6: IMG_2167_p2.png
#   - Copied sample IMG_2167_p2.png and its label.
# Processing sample 7: IMG_2167_p3.png
#   - Copied sample IMG_2167_p3.png and its label.
# Processing sample 8: IMG_2167_p4.png
#   - Copied sample IMG_2167_p4.png and its label.
# Processing sample 9: IMG_2167_p5.png
#   - Copied sample IMG_2167_p5.png and its label.
# Processing sample 10: IMG_2167_p6.png
#   - Copied sample IMG_2167_p6.png and its label.
# Processing sample 11: IMG_2167_p7.png
#   - Copied sample IMG_2167_p7.png and its label.
# Processing sample 12: IMG_2167_p8.png
#   - Copied sample IMG_2167_p8.png and its label.
# Processing sample 13: IMG_2167_p9.png
#   - Copied sample IMG_2167_p9.png and its label.
# Skipping raw image IMG_2276.JPG
# Processing sample 2: IMG_2276_p0.png
#   - Copied sample IMG_2276_p0.png and its label.
# Processing sample 3: IMG_2276_p10.png
#   - Copied sample IMG_2276_p10.png and its label.
# Processing sample 4: IMG_2276_p11.png
#   - Copied sample IMG_2276_p11.png and its label.
# Processing sample 5: IMG_2276_p12.png
#   - Copied sample IMG_2276_p12.png and its label.
# Processing sample 6: IMG_2276_p1.png
#   - Copied sample IMG_2276_p1.png and its label.
# Processing sample 7: IMG_2276_p2.png
#   - Copied sample IMG_2276_p2.png and its label.
# Processing sample 8: IMG_2276_p3.png
#   - Copied sample IMG_2276_p3.png and its label.
# Processing sample 9: IMG_2276_p4.png
#   - Copied sample IMG_2276_p4.png and its label.
# Processing sample 10: IMG_2276_p5.png
#   - Copied sample IMG_2276_p5.png and its label.
# Processing sample 11: IMG_2276_p6.png
#   - Copied sample IMG_2276_p6.png and its label.
# Processing sample 12: IMG_2276_p7.png
#   - Copied sample IMG_2276_p7.png and its label.
# Processing sample 13: IMG_2276_p8.png
#   - Copied sample IMG_2276_p8.png and its label.
# Processing sample 14: IMG_2276_p9.png
#   - Copied sample IMG_2276_p9.png and its label.
# Skipping raw image IMG_0547.JPG
# Processing sample 2: IMG_0547_p0.png
#   - Copied sample IMG_0547_p0.png and its label.
# Processing sample 3: IMG_0547_p10.png
#   - Copied sample IMG_0547_p10.png and its label.
# Processing sample 4: IMG_0547_p11.png
#   - Copied sample IMG_0547_p11.png and its label.
# Processing sample 5: IMG_0547_p12.png
#   - Copied sample IMG_0547_p12.png and its label.
# Processing sample 6: IMG_0547_p13.png
#   - Copied sample IMG_0547_p13.png and its label.
# Processing sample 7: IMG_0547_p14.png
#   - Copied sample IMG_0547_p14.png and its label.
# Processing sample 8: IMG_0547_p1.png
#   - Copied sample IMG_0547_p1.png and its label.
# Skipping sample IMG_0547_p2.png due to label status mismatch
# Processing sample 10: IMG_0547_p3.png
#   - Copied sample IMG_0547_p3.png and its label.
# Processing sample 11: IMG_0547_p4.png
#   - Copied sample IMG_0547_p4.png and its label.
# Processing sample 12: IMG_0547_p5.png
#   - Copied sample IMG_0547_p5.png and its label.
# Processing sample 13: IMG_0547_p6.png
#   - Copied sample IMG_0547_p6.png and its label.
# Processing sample 14: IMG_0547_p7.png
#   - Copied sample IMG_0547_p7.png and its label.
# Processing sample 15: IMG_0547_p8.png
#   - Copied sample IMG_0547_p8.png and its label.
# Processing sample 16: IMG_0547_p9.png
#   - Copied sample IMG_0547_p9.png and its label.
# Skipping raw image IMG_1857.JPG
# Skipping sample IMG_1857_p0.png due to label status mismatch
# Processing sample 3: IMG_1857_p10.png
#   - Copied sample IMG_1857_p10.png and its label.
# Processing sample 4: IMG_1857_p1.png
#   - Copied sample IMG_1857_p1.png and its label.
# Processing sample 5: IMG_1857_p2.png
#   - Copied sample IMG_1857_p2.png and its label.
# Processing sample 6: IMG_1857_p3.png
#   - Copied sample IMG_1857_p3.png and its label.
# Processing sample 7: IMG_1857_p4.png
#   - Copied sample IMG_1857_p4.png and its label.
# Processing sample 8: IMG_1857_p5.png
#   - Copied sample IMG_1857_p5.png and its label.
# Processing sample 9: IMG_1857_p6.png
#   - Copied sample IMG_1857_p6.png and its label.
# Processing sample 10: IMG_1857_p7.png
#   - Copied sample IMG_1857_p7.png and its label.
# Processing sample 11: IMG_1857_p8.png
#   - Copied sample IMG_1857_p8.png and its label.
# Processing sample 12: IMG_1857_p9.png
#   - Copied sample IMG_1857_p9.png and its label.
# Skipping raw image IMG_0562.JPG
# Skipping sample IMG_0562_p0.png due to label status mismatch
# Processing sample 3: IMG_0562_p1.png
#   - Copied sample IMG_0562_p1.png and its label.
# Processing sample 4: IMG_0562_p2.png
#   - Copied sample IMG_0562_p2.png and its label.
# Processing sample 5: IMG_0562_p3.png
#   - Copied sample IMG_0562_p3.png and its label.
# Processing sample 6: IMG_0562_p4.png
#   - Copied sample IMG_0562_p4.png and its label.
# Processing sample 7: IMG_0562_p5.png
#   - Copied sample IMG_0562_p5.png and its label.
# Processing sample 8: IMG_0562_p6.png
#   - Copied sample IMG_0562_p6.png and its label.
# Processing sample 9: IMG_0562_p7.png
#   - Copied sample IMG_0562_p7.png and its label.
# Processing sample 10: IMG_0562_p8.png
#   - Copied sample IMG_0562_p8.png and its label.
# Processing sample 11: IMG_0562_p9.png
#   - Copied sample IMG_0562_p9.png and its label.
# Skipping raw image IMG_1082.JPG
# Skipping sample IMG_1082_p0.png due to label status mismatch
# Processing sample 3: IMG_1082_p1.png
#   - Copied sample IMG_1082_p1.png and its label.
# Processing sample 4: IMG_1082_p2.png
#   - Copied sample IMG_1082_p2.png and its label.
# Processing sample 5: IMG_1082_p3.png
#   - Copied sample IMG_1082_p3.png and its label.
# Processing sample 6: IMG_1082_p4.png
#   - Copied sample IMG_1082_p4.png and its label.
# Processing sample 7: IMG_1082_p5.png
#   - Copied sample IMG_1082_p5.png and its label.
# Processing sample 8: IMG_1082_p6.png
#   - Copied sample IMG_1082_p6.png and its label.
# Processing sample 9: IMG_1082_p7.png
#   - Copied sample IMG_1082_p7.png and its label.
# Skipping raw image IMG_2134.JPG
# Processing sample 2: IMG_2134_p0.png
#   - Copied sample IMG_2134_p0.png and its label.
# Processing sample 3: IMG_2134_p10.png
#   - Copied sample IMG_2134_p10.png and its label.
# Processing sample 4: IMG_2134_p1.png
#   - Copied sample IMG_2134_p1.png and its label.
# Processing sample 5: IMG_2134_p2.png
#   - Copied sample IMG_2134_p2.png and its label.
# Processing sample 6: IMG_2134_p3.png
#   - Copied sample IMG_2134_p3.png and its label.
# Processing sample 7: IMG_2134_p4.png
#   - Copied sample IMG_2134_p4.png and its label.
# Processing sample 8: IMG_2134_p5.png
#   - Copied sample IMG_2134_p5.png and its label.
# Processing sample 9: IMG_2134_p6.png
#   - Copied sample IMG_2134_p6.png and its label.
# Processing sample 10: IMG_2134_p7.png
#   - Copied sample IMG_2134_p7.png and its label.
# Processing sample 11: IMG_2134_p8.png
#   - Copied sample IMG_2134_p8.png and its label.
# Processing sample 12: IMG_2134_p9.png
#   - Copied sample IMG_2134_p9.png and its label.
# Skipping raw image IMG_9998.JPG
# Processing sample 2: IMG_9998_p0.png
#   - Copied sample IMG_9998_p0.png and its label.
# Processing sample 3: IMG_9998_p10.png
#   - Copied sample IMG_9998_p10.png and its label.
# Processing sample 4: IMG_9998_p1.png
#   - Copied sample IMG_9998_p1.png and its label.
# Processing sample 5: IMG_9998_p2.png
#   - Copied sample IMG_9998_p2.png and its label.
# Processing sample 6: IMG_9998_p3.png
#   - Copied sample IMG_9998_p3.png and its label.
# Processing sample 7: IMG_9998_p4.png
#   - Copied sample IMG_9998_p4.png and its label.
# Processing sample 8: IMG_9998_p5.png
#   - Copied sample IMG_9998_p5.png and its label.
# Processing sample 9: IMG_9998_p6.png
#   - Copied sample IMG_9998_p6.png and its label.
# Processing sample 10: IMG_9998_p7.png
#   - Copied sample IMG_9998_p7.png and its label.
# Processing sample 11: IMG_9998_p8.png
#   - Copied sample IMG_9998_p8.png and its label.
# Processing sample 12: IMG_9998_p9.png
#   - Copied sample IMG_9998_p9.png and its label.
# Skipping raw image IMG_0581.JPG
# Processing sample 2: IMG_0581_p0.png
#   - Copied sample IMG_0581_p0.png and its label.
# Processing sample 3: IMG_0581_p10.png
#   - Copied sample IMG_0581_p10.png and its label.
# Processing sample 4: IMG_0581_p11.png
#   - Copied sample IMG_0581_p11.png and its label.
# Processing sample 5: IMG_0581_p12.png
#   - Copied sample IMG_0581_p12.png and its label.
# Processing sample 6: IMG_0581_p13.png
#   - Copied sample IMG_0581_p13.png and its label.
# Processing sample 7: IMG_0581_p1.png
#   - Copied sample IMG_0581_p1.png and its label.
# Processing sample 8: IMG_0581_p2.png
#   - Copied sample IMG_0581_p2.png and its label.
# Processing sample 9: IMG_0581_p3.png
#   - Copied sample IMG_0581_p3.png and its label.
# Processing sample 10: IMG_0581_p4.png
#   - Copied sample IMG_0581_p4.png and its label.
# Processing sample 11: IMG_0581_p5.png
#   - Copied sample IMG_0581_p5.png and its label.
# Processing sample 12: IMG_0581_p6.png
#   - Copied sample IMG_0581_p6.png and its label.
# Processing sample 13: IMG_0581_p7.png
#   - Copied sample IMG_0581_p7.png and its label.
# Processing sample 14: IMG_0581_p8.png
#   - Copied sample IMG_0581_p8.png and its label.
# Processing sample 15: IMG_0581_p9.png
#   - Copied sample IMG_0581_p9.png and its label.
# Skipping raw image IMG_1085.JPG
# Processing sample 2: IMG_1085_p0.png
#   - Copied sample IMG_1085_p0.png and its label.
# Processing sample 3: IMG_1085_p10.png
#   - Copied sample IMG_1085_p10.png and its label.
# Processing sample 4: IMG_1085_p1.png
#   - Copied sample IMG_1085_p1.png and its label.
# Processing sample 5: IMG_1085_p2.png
#   - Copied sample IMG_1085_p2.png and its label.
# Skipping sample IMG_1085_p3.png due to label status mismatch
# Processing sample 7: IMG_1085_p4.png
#   - Copied sample IMG_1085_p4.png and its label.
# Processing sample 8: IMG_1085_p5.png
#   - Copied sample IMG_1085_p5.png and its label.
# Processing sample 9: IMG_1085_p6.png
#   - Copied sample IMG_1085_p6.png and its label.
# Processing sample 10: IMG_1085_p7.png
#   - Copied sample IMG_1085_p7.png and its label.
# Processing sample 11: IMG_1085_p8.png
#   - Copied sample IMG_1085_p8.png and its label.
# Processing sample 12: IMG_1085_p9.png
#   - Copied sample IMG_1085_p9.png and its label.
# Skipping raw image IMG_1827.JPG
# Processing sample 2: IMG_1827_p0.png
#   - Copied sample IMG_1827_p0.png and its label.
# Processing sample 3: IMG_1827_p10.png
#   - Copied sample IMG_1827_p10.png and its label.
# Processing sample 4: IMG_1827_p11.png
#   - Copied sample IMG_1827_p11.png and its label.
# Processing sample 5: IMG_1827_p1.png
#   - Copied sample IMG_1827_p1.png and its label.
# Processing sample 6: IMG_1827_p2.png
#   - Copied sample IMG_1827_p2.png and its label.
# Processing sample 7: IMG_1827_p3.png
#   - Copied sample IMG_1827_p3.png and its label.
# Processing sample 8: IMG_1827_p4.png
#   - Copied sample IMG_1827_p4.png and its label.
# Processing sample 9: IMG_1827_p5.png
#   - Copied sample IMG_1827_p5.png and its label.
# Processing sample 10: IMG_1827_p6.png
#   - Copied sample IMG_1827_p6.png and its label.
# Processing sample 11: IMG_1827_p7.png
#   - Copied sample IMG_1827_p7.png and its label.
# Processing sample 12: IMG_1827_p8.png
#   - Copied sample IMG_1827_p8.png and its label.
# Processing sample 13: IMG_1827_p9.png
#   - Copied sample IMG_1827_p9.png and its label.
# Skipping raw image IMG_1182.JPG
# Skipping sample IMG_1182_p0.png due to label status mismatch
# Processing sample 3: IMG_1182_p1.png
#   - Copied sample IMG_1182_p1.png and its label.
# Processing sample 4: IMG_1182_p2.png
#   - Copied sample IMG_1182_p2.png and its label.
# Skipping sample IMG_1182_p3.png due to label status mismatch
# Processing sample 6: IMG_1182_p4.png
#   - Copied sample IMG_1182_p4.png and its label.
# Processing sample 7: IMG_1182_p5.png
#   - Copied sample IMG_1182_p5.png and its label.
# Processing sample 8: IMG_1182_p6.png
#   - Copied sample IMG_1182_p6.png and its label.
# Processing sample 9: IMG_1182_p7.png
#   - Copied sample IMG_1182_p7.png and its label.
# Processing sample 10: IMG_1182_p8.png
#   - Copied sample IMG_1182_p8.png and its label.
# Processing sample 11: IMG_1182_p9.png
#   - Copied sample IMG_1182_p9.png and its label.
# Skipping raw image IMG_2145.JPG
# Processing sample 2: IMG_2145_p0.png
#   - Copied sample IMG_2145_p0.png and its label.
# Processing sample 3: IMG_2145_p11.png
#   - Copied sample IMG_2145_p11.png and its label.
# Processing sample 4: IMG_2145_p1.png
#   - Copied sample IMG_2145_p1.png and its label.
# Processing sample 5: IMG_2145_p3.png
#   - Copied sample IMG_2145_p3.png and its label.
# Processing sample 6: IMG_2145_p4.png
#   - Copied sample IMG_2145_p4.png and its label.
# Processing sample 7: IMG_2145_p5.png
#   - Copied sample IMG_2145_p5.png and its label.
# Processing sample 8: IMG_2145_p6.png
#   - Copied sample IMG_2145_p6.png and its label.
# Processing sample 9: IMG_2145_p7.png
#   - Copied sample IMG_2145_p7.png and its label.
# Processing sample 10: IMG_2145_p8.png
#   - Copied sample IMG_2145_p8.png and its label.
# Processing sample 11: IMG_2145_p9.png
#   - Copied sample IMG_2145_p9.png and its label.
# Skipping raw image IMG_0540.JPG
# Processing sample 2: IMG_0540_p0.png
#   - Copied sample IMG_0540_p0.png and its label.
# Processing sample 3: IMG_0540_p10.png
#   - Copied sample IMG_0540_p10.png and its label.
# Processing sample 4: IMG_0540_p11.png
#   - Copied sample IMG_0540_p11.png and its label.
# Processing sample 5: IMG_0540_p12.png
#   - Copied sample IMG_0540_p12.png and its label.
# Skipping sample IMG_0540_p1.png due to label status mismatch
# Processing sample 7: IMG_0540_p2.png
#   - Copied sample IMG_0540_p2.png and its label.
# Processing sample 8: IMG_0540_p3.png
#   - Copied sample IMG_0540_p3.png and its label.
# Processing sample 9: IMG_0540_p4.png
#   - Copied sample IMG_0540_p4.png and its label.
# Processing sample 10: IMG_0540_p5.png
#   - Copied sample IMG_0540_p5.png and its label.
# Processing sample 11: IMG_0540_p6.png
#   - Copied sample IMG_0540_p6.png and its label.
# Processing sample 12: IMG_0540_p7.png
#   - Copied sample IMG_0540_p7.png and its label.
# Processing sample 13: IMG_0540_p8.png
#   - Copied sample IMG_0540_p8.png and its label.
# Processing sample 14: IMG_0540_p9.png
#   - Copied sample IMG_0540_p9.png and its label.
# Skipping raw image IMG_0546.JPG
# Skipping sample IMG_0546_p0.png due to label status mismatch
# Processing sample 3: IMG_0546_p10.png
#   - Copied sample IMG_0546_p10.png and its label.
# Skipping sample IMG_0546_p1.png due to label status mismatch
# Processing sample 5: IMG_0546_p2.png
#   - Copied sample IMG_0546_p2.png and its label.
# Processing sample 6: IMG_0546_p3.png
#   - Copied sample IMG_0546_p3.png and its label.
# Processing sample 7: IMG_0546_p4.png
#   - Copied sample IMG_0546_p4.png and its label.
# Processing sample 8: IMG_0546_p5.png
#   - Copied sample IMG_0546_p5.png and its label.
# Processing sample 9: IMG_0546_p6.png
#   - Copied sample IMG_0546_p6.png and its label.
# Processing sample 10: IMG_0546_p7.png
#   - Copied sample IMG_0546_p7.png and its label.
# Processing sample 11: IMG_0546_p8.png
#   - Copied sample IMG_0546_p8.png and its label.
# Processing sample 12: IMG_0546_p9.png
#   - Copied sample IMG_0546_p9.png and its label.
# Skipping raw image IMG_2242.JPG
# Processing sample 2: IMG_2242_p11.png
#   - Copied sample IMG_2242_p11.png and its label.
# Processing sample 3: IMG_2242_p1.png
#   - Copied sample IMG_2242_p1.png and its label.
# Processing sample 4: IMG_2242_p2.png
#   - Copied sample IMG_2242_p2.png and its label.
# Processing sample 5: IMG_2242_p3.png
#   - Copied sample IMG_2242_p3.png and its label.
# Processing sample 6: IMG_2242_p4.png
#   - Copied sample IMG_2242_p4.png and its label.
# Processing sample 7: IMG_2242_p5.png
#   - Copied sample IMG_2242_p5.png and its label.
# Processing sample 8: IMG_2242_p6.png
#   - Copied sample IMG_2242_p6.png and its label.
# Processing sample 9: IMG_2242_p7.png
#   - Copied sample IMG_2242_p7.png and its label.
# Processing sample 10: IMG_2242_p8.png
#   - Copied sample IMG_2242_p8.png and its label.
# Processing sample 11: IMG_2242_p9.png
#   - Copied sample IMG_2242_p9.png and its label.
# Skipping raw image IMG_0001.JPG
# Processing sample 2: IMG_0001_p0.png
#   - Copied sample IMG_0001_p0.png and its label.
# Processing sample 3: IMG_0001_p1.png
#   - Copied sample IMG_0001_p1.png and its label.
# Processing sample 4: IMG_0001_p2.png
#   - Copied sample IMG_0001_p2.png and its label.
# Processing sample 5: IMG_0001_p3.png
#   - Copied sample IMG_0001_p3.png and its label.
# Processing sample 6: IMG_0001_p4.png
#   - Copied sample IMG_0001_p4.png and its label.
# Processing sample 7: IMG_0001_p5.png
#   - Copied sample IMG_0001_p5.png and its label.
# Processing sample 8: IMG_0001_p6.png
#   - Copied sample IMG_0001_p6.png and its label.
# Processing sample 9: IMG_0001_p7.png
#   - Copied sample IMG_0001_p7.png and its label.
# Processing sample 10: IMG_0001_p8.png
#   - Copied sample IMG_0001_p8.png and its label.
# Skipping raw image IMG_0545.JPG
# Processing sample 2: IMG_0545_p0.png
#   - Copied sample IMG_0545_p0.png and its label.
# Processing sample 3: IMG_0545_p10.png
#   - Copied sample IMG_0545_p10.png and its label.
# Processing sample 4: IMG_0545_p11.png
#   - Copied sample IMG_0545_p11.png and its label.
# Processing sample 5: IMG_0545_p12.png
#   - Copied sample IMG_0545_p12.png and its label.
# Processing sample 6: IMG_0545_p1.png
#   - Copied sample IMG_0545_p1.png and its label.
# Processing sample 7: IMG_0545_p2.png
#   - Copied sample IMG_0545_p2.png and its label.
# Processing sample 8: IMG_0545_p3.png
#   - Copied sample IMG_0545_p3.png and its label.
# Processing sample 9: IMG_0545_p4.png
#   - Copied sample IMG_0545_p4.png and its label.
# Skipping sample IMG_0545_p5.png due to label status mismatch
# Processing sample 11: IMG_0545_p6.png
#   - Copied sample IMG_0545_p6.png and its label.
# Processing sample 12: IMG_0545_p7.png
#   - Copied sample IMG_0545_p7.png and its label.
# Processing sample 13: IMG_0545_p8.png
#   - Copied sample IMG_0545_p8.png and its label.
# Processing sample 14: IMG_0545_p9.png
#   - Copied sample IMG_0545_p9.png and its label.
# Skipping raw image IMG_1784.JPG
# Processing sample 2: IMG_1784_p0.png
#   - Copied sample IMG_1784_p0.png and its label.
# Processing sample 3: IMG_1784_p10.png
#   - Copied sample IMG_1784_p10.png and its label.
# Processing sample 4: IMG_1784_p1.png
#   - Copied sample IMG_1784_p1.png and its label.
# Processing sample 5: IMG_1784_p2.png
#   - Copied sample IMG_1784_p2.png and its label.
# Processing sample 6: IMG_1784_p3.png
#   - Copied sample IMG_1784_p3.png and its label.
# Processing sample 7: IMG_1784_p4.png
#   - Copied sample IMG_1784_p4.png and its label.
# Processing sample 8: IMG_1784_p5.png
#   - Copied sample IMG_1784_p5.png and its label.
# Processing sample 9: IMG_1784_p6.png
#   - Copied sample IMG_1784_p6.png and its label.
# Processing sample 10: IMG_1784_p7.png
#   - Copied sample IMG_1784_p7.png and its label.
# Processing sample 11: IMG_1784_p8.png
#   - Copied sample IMG_1784_p8.png and its label.
# Processing sample 12: IMG_1784_p9.png
#   - Copied sample IMG_1784_p9.png and its label.
# Skipping raw image IMG_1875.JPG
# Skipping sample IMG_1875_p0.png due to label status mismatch
# Processing sample 3: IMG_1875_p10.png
#   - Copied sample IMG_1875_p10.png and its label.
# Processing sample 4: IMG_1875_p11.png
#   - Copied sample IMG_1875_p11.png and its label.
# Processing sample 5: IMG_1875_p1.png
#   - Copied sample IMG_1875_p1.png and its label.
# Processing sample 6: IMG_1875_p2.png
#   - Copied sample IMG_1875_p2.png and its label.
# Skipping sample IMG_1875_p3.png due to label status mismatch
# Processing sample 8: IMG_1875_p4.png
#   - Copied sample IMG_1875_p4.png and its label.
# Skipping sample IMG_1875_p5.png due to label status mismatch
# Skipping sample IMG_1875_p6.png due to label status mismatch
# Processing sample 11: IMG_1875_p7.png
#   - Copied sample IMG_1875_p7.png and its label.
# Skipping sample IMG_1875_p8.png due to label status mismatch
# Processing sample 13: IMG_1875_p9.png
#   - Copied sample IMG_1875_p9.png and its label.
# Skipping raw image IMG_1111.JPG
# Processing sample 2: IMG_1111_p0.png
#   - Copied sample IMG_1111_p0.png and its label.
# Skipping sample IMG_1111_p1.png due to label status mismatch
# Processing sample 4: IMG_1111_p2.png
#   - Copied sample IMG_1111_p2.png and its label.
# Processing sample 5: IMG_1111_p3.png
#   - Copied sample IMG_1111_p3.png and its label.
# Processing sample 6: IMG_1111_p4.png
#   - Copied sample IMG_1111_p4.png and its label.
# Processing sample 7: IMG_1111_p5.png
#   - Copied sample IMG_1111_p5.png and its label.
# Skipping raw image IMG_1818.JPG
# Processing sample 2: IMG_1818_p0.png
#   - Copied sample IMG_1818_p0.png and its label.
# Processing sample 3: IMG_1818_p10.png
#   - Copied sample IMG_1818_p10.png and its label.
# Processing sample 4: IMG_1818_p1.png
#   - Copied sample IMG_1818_p1.png and its label.
# Processing sample 5: IMG_1818_p2.png
#   - Copied sample IMG_1818_p2.png and its label.
# Processing sample 6: IMG_1818_p3.png
#   - Copied sample IMG_1818_p3.png and its label.
# Processing sample 7: IMG_1818_p4.png
#   - Copied sample IMG_1818_p4.png and its label.
# Processing sample 8: IMG_1818_p5.png
#   - Copied sample IMG_1818_p5.png and its label.
# Processing sample 9: IMG_1818_p6.png
#   - Copied sample IMG_1818_p6.png and its label.
# Processing sample 10: IMG_1818_p7.png
#   - Copied sample IMG_1818_p7.png and its label.
# Processing sample 11: IMG_1818_p8.png
#   - Copied sample IMG_1818_p8.png and its label.
# Processing sample 12: IMG_1818_p9.png
#   - Copied sample IMG_1818_p9.png and its label.

# %%
# add the images to the train dataset
test_dataset_identifier = f"etaylor/{dataset_name_test}"
for index, row in test_df.iterrows():
    image_number = row["image_number"]
    week, zoom_type = config.find_image_details(image_number)
    dataset_identifier = segments_handler.get_segments_dataset_identifier(image_number, week, zoom_type)
    segments_handler.copy_dataset_contents(dataset_identifier, test_dataset_identifier, verbose=True, only_patches=True)
# Out:
# Skipping raw image IMG_0542.JPG
# Processing sample 2: IMG_0542_p0.png
#   - Copied sample IMG_0542_p0.png and its label.
# Processing sample 3: IMG_0542_p10.png
#   - Copied sample IMG_0542_p10.png and its label.
# Skipping sample IMG_0542_p11.png due to label status mismatch
# Processing sample 5: IMG_0542_p12.png
#   - Copied sample IMG_0542_p12.png and its label.
# Skipping sample IMG_0542_p1.png due to label status mismatch
# Processing sample 7: IMG_0542_p2.png
#   - Copied sample IMG_0542_p2.png and its label.
# Processing sample 8: IMG_0542_p3.png
#   - Copied sample IMG_0542_p3.png and its label.
# Skipping sample IMG_0542_p4.png due to label status mismatch
# Processing sample 10: IMG_0542_p5.png
#   - Copied sample IMG_0542_p5.png and its label.
# Processing sample 11: IMG_0542_p6.png
#   - Copied sample IMG_0542_p6.png and its label.
# Processing sample 12: IMG_0542_p7.png
#   - Copied sample IMG_0542_p7.png and its label.
# Processing sample 13: IMG_0542_p8.png
#   - Copied sample IMG_0542_p8.png and its label.
# Skipping sample IMG_0542_p9.png due to label status mismatch
# Skipping raw image IMG_2198.JPG
# Processing sample 2: IMG_2198_p0.png
#   - Copied sample IMG_2198_p0.png and its label.
# Processing sample 3: IMG_2198_p10.png
#   - Copied sample IMG_2198_p10.png and its label.
# Processing sample 4: IMG_2198_p11.png
#   - Copied sample IMG_2198_p11.png and its label.
# Processing sample 5: IMG_2198_p12.png
#   - Copied sample IMG_2198_p12.png and its label.
# Processing sample 6: IMG_2198_p1.png
#   - Copied sample IMG_2198_p1.png and its label.
# Processing sample 7: IMG_2198_p2.png
#   - Copied sample IMG_2198_p2.png and its label.
# Processing sample 8: IMG_2198_p3.png
#   - Copied sample IMG_2198_p3.png and its label.
# Processing sample 9: IMG_2198_p4.png
#   - Copied sample IMG_2198_p4.png and its label.
# Processing sample 10: IMG_2198_p5.png
#   - Copied sample IMG_2198_p5.png and its label.
# Processing sample 11: IMG_2198_p6.png
#   - Copied sample IMG_2198_p6.png and its label.
# Processing sample 12: IMG_2198_p7.png
#   - Copied sample IMG_2198_p7.png and its label.
# Processing sample 13: IMG_2198_p8.png
#   - Copied sample IMG_2198_p8.png and its label.
# Processing sample 14: IMG_2198_p9.png
#   - Copied sample IMG_2198_p9.png and its label.
# Skipping raw image IMG_1753.JPG
# Skipping sample IMG_1753_p0.png due to label status mismatch
# Processing sample 3: IMG_1753_p1.png
#   - Copied sample IMG_1753_p1.png and its label.
# Processing sample 4: IMG_1753_p2.png
#   - Copied sample IMG_1753_p2.png and its label.
# Processing sample 5: IMG_1753_p3.png
#   - Copied sample IMG_1753_p3.png and its label.
# Processing sample 6: IMG_1753_p4.png
#   - Copied sample IMG_1753_p4.png and its label.
# Processing sample 7: IMG_1753_p5.png
#   - Copied sample IMG_1753_p5.png and its label.
# Processing sample 8: IMG_1753_p6.png
#   - Copied sample IMG_1753_p6.png and its label.
# Skipping sample IMG_1753_p7.png due to label status mismatch
# Skipping raw image IMG_1093.JPG
# Processing sample 2: IMG_1093_p0.png
#   - Copied sample IMG_1093_p0.png and its label.
# Processing sample 3: IMG_1093_p10.png
#   - Copied sample IMG_1093_p10.png and its label.
# Processing sample 4: IMG_1093_p11.png
#   - Copied sample IMG_1093_p11.png and its label.
# Processing sample 5: IMG_1093_p12.png
#   - Copied sample IMG_1093_p12.png and its label.
# Processing sample 6: IMG_1093_p1.png
#   - Copied sample IMG_1093_p1.png and its label.
# Processing sample 7: IMG_1093_p2.png
#   - Copied sample IMG_1093_p2.png and its label.
# Processing sample 8: IMG_1093_p3.png
#   - Copied sample IMG_1093_p3.png and its label.
# Processing sample 9: IMG_1093_p4.png
#   - Copied sample IMG_1093_p4.png and its label.
# Processing sample 10: IMG_1093_p5.png
#   - Copied sample IMG_1093_p5.png and its label.
# Processing sample 11: IMG_1093_p6.png
#   - Copied sample IMG_1093_p6.png and its label.
# Processing sample 12: IMG_1093_p7.png
#   - Copied sample IMG_1093_p7.png and its label.
# Processing sample 13: IMG_1093_p8.png
#   - Copied sample IMG_1093_p8.png and its label.
# Processing sample 14: IMG_1093_p9.png
#   - Copied sample IMG_1093_p9.png and its label.
# Skipping raw image IMG_0019.JPG
# Processing sample 2: IMG_0019_p0.png
#   - Copied sample IMG_0019_p0.png and its label.
# Processing sample 3: IMG_0019_p10.png
#   - Copied sample IMG_0019_p10.png and its label.
# Processing sample 4: IMG_0019_p1.png
#   - Copied sample IMG_0019_p1.png and its label.
# Processing sample 5: IMG_0019_p2.png
#   - Copied sample IMG_0019_p2.png and its label.
# Processing sample 6: IMG_0019_p3.png
#   - Copied sample IMG_0019_p3.png and its label.
# Processing sample 7: IMG_0019_p4.png
#   - Copied sample IMG_0019_p4.png and its label.
# Processing sample 8: IMG_0019_p5.png
#   - Copied sample IMG_0019_p5.png and its label.
# Processing sample 9: IMG_0019_p6.png
#   - Copied sample IMG_0019_p6.png and its label.
# Processing sample 10: IMG_0019_p7.png
#   - Copied sample IMG_0019_p7.png and its label.
# Processing sample 11: IMG_0019_p8.png
#   - Copied sample IMG_0019_p8.png and its label.
# Processing sample 12: IMG_0019_p9.png
#   - Copied sample IMG_0019_p9.png and its label.
# Skipping raw image IMG_1096.JPG
# Processing sample 2: IMG_1096_p0.png
#   - Copied sample IMG_1096_p0.png and its label.
# Processing sample 3: IMG_1096_p10.png
#   - Copied sample IMG_1096_p10.png and its label.
# Processing sample 4: IMG_1096_p11.png
#   - Copied sample IMG_1096_p11.png and its label.
# Processing sample 5: IMG_1096_p12.png
#   - Copied sample IMG_1096_p12.png and its label.
# Processing sample 6: IMG_1096_p1.png
#   - Copied sample IMG_1096_p1.png and its label.
# Skipping sample IMG_1096_p2.png due to label status mismatch
# Processing sample 8: IMG_1096_p3.png
#   - Copied sample IMG_1096_p3.png and its label.
# Processing sample 9: IMG_1096_p4.png
#   - Copied sample IMG_1096_p4.png and its label.
# Skipping sample IMG_1096_p5.png due to label status mismatch
# Processing sample 11: IMG_1096_p6.png
#   - Copied sample IMG_1096_p6.png and its label.
# Processing sample 12: IMG_1096_p7.png
#   - Copied sample IMG_1096_p7.png and its label.
# Processing sample 13: IMG_1096_p8.png
#   - Copied sample IMG_1096_p8.png and its label.
# Processing sample 14: IMG_1096_p9.png
#   - Copied sample IMG_1096_p9.png and its label.
# Skipping raw image IMG_2271.JPG
# Processing sample 2: IMG_2271_p0.png
#   - Copied sample IMG_2271_p0.png and its label.
# Processing sample 3: IMG_2271_p10.png
#   - Copied sample IMG_2271_p10.png and its label.
# Processing sample 4: IMG_2271_p11.png
#   - Copied sample IMG_2271_p11.png and its label.
# Skipping sample IMG_2271_p12.png due to label status mismatch
# Processing sample 6: IMG_2271_p13.png
#   - Copied sample IMG_2271_p13.png and its label.
# Processing sample 7: IMG_2271_p1.png
#   - Copied sample IMG_2271_p1.png and its label.
# Processing sample 8: IMG_2271_p2.png
#   - Copied sample IMG_2271_p2.png and its label.
# Processing sample 9: IMG_2271_p3.png
#   - Copied sample IMG_2271_p3.png and its label.
# Processing sample 10: IMG_2271_p4.png
#   - Copied sample IMG_2271_p4.png and its label.
# Processing sample 11: IMG_2271_p5.png
#   - Copied sample IMG_2271_p5.png and its label.
# Processing sample 12: IMG_2271_p6.png
#   - Copied sample IMG_2271_p6.png and its label.
# Processing sample 13: IMG_2271_p7.png
#   - Copied sample IMG_2271_p7.png and its label.
# Processing sample 14: IMG_2271_p8.png
#   - Copied sample IMG_2271_p8.png and its label.
# Processing sample 15: IMG_2271_p9.png
#   - Copied sample IMG_2271_p9.png and its label.
# Skipping raw image IMG_2285.JPG
# Processing sample 2: IMG_2285_p0.png
#   - Copied sample IMG_2285_p0.png and its label.
# Processing sample 3: IMG_2285_p10.png
#   - Copied sample IMG_2285_p10.png and its label.
# Processing sample 4: IMG_2285_p11.png
#   - Copied sample IMG_2285_p11.png and its label.
# Processing sample 5: IMG_2285_p12.png
#   - Copied sample IMG_2285_p12.png and its label.
# Processing sample 6: IMG_2285_p13.png
#   - Copied sample IMG_2285_p13.png and its label.
# Processing sample 7: IMG_2285_p1.png
#   - Copied sample IMG_2285_p1.png and its label.
# Processing sample 8: IMG_2285_p2.png
#   - Copied sample IMG_2285_p2.png and its label.
# Processing sample 9: IMG_2285_p3.png
#   - Copied sample IMG_2285_p3.png and its label.
# Processing sample 10: IMG_2285_p4.png
#   - Copied sample IMG_2285_p4.png and its label.
# Processing sample 11: IMG_2285_p5.png
#   - Copied sample IMG_2285_p5.png and its label.
# Processing sample 12: IMG_2285_p6.png
#   - Copied sample IMG_2285_p6.png and its label.
# Processing sample 13: IMG_2285_p7.png
#   - Copied sample IMG_2285_p7.png and its label.
# Processing sample 14: IMG_2285_p8.png
#   - Copied sample IMG_2285_p8.png and its label.
# Processing sample 15: IMG_2285_p9.png
#   - Copied sample IMG_2285_p9.png and its label.
# Skipping raw image IMG_1079.JPG
# Processing sample 2: IMG_1079_p0.png
#   - Copied sample IMG_1079_p0.png and its label.
# Processing sample 3: IMG_1079_p1.png
#   - Copied sample IMG_1079_p1.png and its label.
# Processing sample 4: IMG_1079_p2.png
#   - Copied sample IMG_1079_p2.png and its label.
# Processing sample 5: IMG_1079_p3.png
#   - Copied sample IMG_1079_p3.png and its label.
# Processing sample 6: IMG_1079_p4.png
#   - Copied sample IMG_1079_p4.png and its label.
# Processing sample 7: IMG_1079_p5.png
#   - Copied sample IMG_1079_p5.png and its label.
# Processing sample 8: IMG_1079_p6.png
#   - Copied sample IMG_1079_p6.png and its label.
# Processing sample 9: IMG_1079_p7.png
#   - Copied sample IMG_1079_p7.png and its label.
# Skipping raw image IMG_0058.JPG
# Processing sample 2: IMG_0058_p0.png
#   - Copied sample IMG_0058_p0.png and its label.
# Processing sample 3: IMG_0058_p1.png
#   - Copied sample IMG_0058_p1.png and its label.
# Processing sample 4: IMG_0058_p2.png
#   - Copied sample IMG_0058_p2.png and its label.
# Processing sample 5: IMG_0058_p3.png
#   - Copied sample IMG_0058_p3.png and its label.
# Processing sample 6: IMG_0058_p4.png
#   - Copied sample IMG_0058_p4.png and its label.
# Processing sample 7: IMG_0058_p5.png
#   - Copied sample IMG_0058_p5.png and its label.
# Processing sample 8: IMG_0058_p6.png
#   - Copied sample IMG_0058_p6.png and its label.
# Processing sample 9: IMG_0058_p7.png
#   - Copied sample IMG_0058_p7.png and its label.
# Processing sample 10: IMG_0058_p8.png
#   - Copied sample IMG_0058_p8.png and its label.
# Processing sample 11: IMG_0058_p9.png
#   - Copied sample IMG_0058_p9.png and its label.
